# %%
import networkx as nx
import argparse
import os
import sys
import numpy as np
import json
import torch
import torchvision
from PIL import Image
import gc
sys.path.append('/root/autodl-tmp/GroundedSAM_src/Grounded-Segment-Anything')
import GroundingDINO.groundingdino.datasets.transforms as T
from GroundingDINO.groundingdino.models import build_model
from GroundingDINO.groundingdino.util.slconfig import SLConfig
from GroundingDINO.groundingdino.util.utils import clean_state_dict, get_phrases_from_posmap

# %%
import pickle
def save_graph(graph, file_path):
    with open(file_path, 'wb') as f:
        pickle.dump(graph, f)

def load_image(image_path):
    # load image
    image_pil = Image.open(image_path).convert("RGB")  # load image

    transform = T.Compose(
        [
            # T.RandomResize([800], max_size=1333),
            T.ToTensor(),
            T.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
        ]
    )
    image, _ = transform(image_pil, None)  # 3, h, w
    return image_pil, image

def load_model(model_config_path, model_checkpoint_path, device):
    args = SLConfig.fromfile(model_config_path)
    args.device = device
    model = build_model(args)
    checkpoint = torch.load(model_checkpoint_path, map_location="cpu")
    load_res = model.load_state_dict(clean_state_dict(checkpoint["model"]), strict=False)
    print(load_res)
    _ = model.eval()
    return model


def get_grounding_output(model, image, caption, box_threshold, text_threshold,device="cpu"):
    caption = caption.lower()
    caption = caption.strip()
    if not caption.endswith("."):
        caption = caption + "."
    model = model.to(device)
    image = image.to(device)
    with torch.no_grad():
        outputs = model(image[None], captions=[caption])
    logits = outputs["pred_logits"].cpu().sigmoid()[0]  # (nq, 256)
    boxes = outputs["pred_boxes"].cpu()[0]  # (nq, 4)
    logits.shape[0]

    # filter output
    logits_filt = logits.clone()
    boxes_filt = boxes.clone()
    filt_mask = logits_filt.max(dim=1)[0] > box_threshold
    logits_filt = logits_filt[filt_mask]  # num_filt, 256
    boxes_filt = boxes_filt[filt_mask]  # num_filt, 4
    logits_filt.shape[0]

    # get phrase
    tokenlizer = model.tokenizer
    tokenized = tokenlizer(caption)
    # build pred
    pred_phrases = []
    scores = []
    for logit, box in zip(logits_filt, boxes_filt):
        pred_phrase = get_phrases_from_posmap(logit > text_threshold, tokenized, tokenlizer)
        pred_phrases.append(pred_phrase + f"({str(logit.max().item())[:4]})")
        scores.append(logit.max().item())

    return boxes_filt, torch.Tensor(scores), pred_phrases

# %%
import mimetypes
import os
from io import BytesIO
from typing import Union
import cv2
import requests
import torch
import transformers
from PIL import Image
from torchvision.transforms import Compose, Resize, ToTensor
from tqdm import tqdm
import sys

sys.path.append("/root/autodl-tmp/Otter/Otter/src/otter_ai")
os.chdir('/root/autodl-tmp/Otter/Otter/src/otter_ai')
sys.path.append("..")
from models.otter.modeling_otter import OtterForConditionalGeneration


# Disable warnings
requests.packages.urllib3.disable_warnings()

# ------------------- Utility Functions -------------------


def get_content_type(file_path):
    content_type, _ = mimetypes.guess_type(file_path)
    return content_type


# ------------------- Image and Video Handling Functions -------------------

def get_image(url: str) -> Union[Image.Image, list]:
    if "://" not in url:  # Local file
        content_type = get_content_type(url)
    else:  # Remote URL
        content_type = requests.head(url, stream=True, verify=False).headers.get("Content-Type")

    if "image" in content_type:
        if "://" not in url:  # Local file
            return Image.open(url)
        else:  # Remote URL
            return Image.open(requests.get(url, stream=True, verify=False).raw)
    else:
        raise ValueError("Invalid content type. Expected image or video.")


# ------------------- OTTER Prompt and Response Functions -------------------


def get_formatted_prompt(prompt: str, in_context_prompts: list = []) -> str:
    in_context_string = ""
    for in_context_prompt, in_context_answer in in_context_prompts:
        in_context_string += f"User: {in_context_prompt} GPT:<answer> {in_context_answer}<|endofchunk|>"
    return f"{in_context_string}User: {prompt} GPT:<answer>"


def get_response(image_list, prompt: str, model=None, image_processor=None, in_context_prompts: list = []) -> str:
    input_data = image_list

    if isinstance(input_data, Image.Image):
        vision_x = image_processor.preprocess([input_data], return_tensors="pt")["pixel_values"].unsqueeze(1).unsqueeze(0)
    elif isinstance(input_data, list):  # list of video frames
        vision_x = image_processor.preprocess(input_data, return_tensors="pt")["pixel_values"].unsqueeze(1).unsqueeze(0)
    else:
        raise ValueError("Invalid input data. Expected PIL Image or list of video frames.")

    print(get_formatted_prompt(prompt, in_context_prompts))
    
    lang_x = model.text_tokenizer(
        [
            get_formatted_prompt(prompt, in_context_prompts),
        ],
        return_tensors="pt",
    )
    bad_words_id = tokenizer(["User:", "GPT1:", "GFT:", "GPT:"], add_special_tokens=False).input_ids
    generated_text = model.generate(
        vision_x=vision_x.to(model.device),
        lang_x=lang_x["input_ids"].to(model.device),
        attention_mask=lang_x["attention_mask"].to(model.device),
        max_new_tokens=512,
        num_beams=3,
        no_repeat_ngram_size=3,
        bad_words_ids=bad_words_id,
    )
    parsed_output = (
        model.text_tokenizer.decode(generated_text[0])
        .split("<answer>")[-1]
        .lstrip()
        .rstrip()
        .split("<|endofchunk|>")[0]
        .lstrip()
        .rstrip()
        .lstrip('"')
        .rstrip('"')
    )
    return parsed_output

def get_response_test(image_list, prompt: str, model=None, image_processor=None) -> str:
    input_data = image_list

    if isinstance(input_data, Image.Image):
        vision_x = image_processor.preprocess([input_data], return_tensors="pt")["pixel_values"].unsqueeze(1).unsqueeze(0)
    elif isinstance(input_data, list):  # list of video frames
        vision_x = image_processor.preprocess(input_data, return_tensors="pt")["pixel_values"].unsqueeze(1).unsqueeze(0)
    else:
        raise ValueError("Invalid input data. Expected PIL Image or list of video frames.")

    lang_x = model.text_tokenizer(
        [
            prompt
        ],
        return_tensors="pt",
    )
    bad_words_id = tokenizer(["User:", "GPT1:", "GFT:", "GPT:"], add_special_tokens=False).input_ids
    generated_text = model.generate(
        vision_x=vision_x.to(model.device),
        lang_x=lang_x["input_ids"].to(model.device),
        attention_mask=lang_x["attention_mask"].to(model.device),
        max_new_tokens=512,
        num_beams=3,
        no_repeat_ngram_size=3,
        bad_words_ids=bad_words_id,
    )
    parsed_output = (
        model.text_tokenizer.decode(generated_text[0])
        .split("<answer>")[-1]
        .lstrip()
        .rstrip()
        .split("<|endofchunk|>")[0]
        .lstrip()
        .rstrip()
        .lstrip('"')
        .rstrip('"')
    )
    return parsed_output

# %%
import pickle
with open('/root/autodl-tmp/Decomposing-Complex-Visual-Textual-Tasks-into-Intermediate-Questions-for-Multi-Modal-COT/decomp_vqav2_1000.pkl', 'rb') as f2:
    decomp = pickle.load(f2)

decomp
# Out:
# {'What is this photo taken looking through?': '1. Is this a photo?\n2. What is the object being looked through in this photo?',
#  'What position is this man playing?': '1. Is there a man in the image?\n2. Is the man playing a sport?\n3. What sport is the man playing?\n4. What position is the man playing?',
#  'What color is the players shirt?': "1. Is there a player in the image?\n2. Is the player wearing a shirt?\n3. What color is the player's shirt?",
#  'Is this man a professional baseball player?': '1. Is there a man in the image?\n2. Is the man engaged in a baseball-related activity?\n3. Does the man possess the physical attributes typically associated with professional baseball players?\n4. Does the man have any identifying features or accessories that suggest he is a professional baseball player?',
#  'What color is the snow?': '1. Is there snow present?\n2. What is the color of the snow?',
#  'What is the person doing?': "1. Is there a person in the image?\n2. What actions or movements can be observed from the person?\n3. Is the person engaged in any specific activity or task?\n4. What objects or tools is the person interacting with, if any?\n5. Can any emotions or expressions be identified from the person's face or body language?\n6. Can any context or surroundings provide clues about the person's actions?\n7. What is the person's overall posture or position?\n8. Is the person interacting with other individuals or animals?\n9. Is the person in motion or stationary?\n10. What is the person's body orientation or directionality?\n11. What is the person's clothing or attire like?\n12. Are there any additional details or elements that might help determine what the person is doing?",
#  'What color is the persons headwear?': "1. Is there a person in the image?\n2. Is the person wearing headwear?\n3. What color is the person's headwear?",
#  "What is in the person's hand?": "1. Is there a person in the image?\n2. Is the person holding something in their hand?\n3. What is the object in the person's hand?",
#  'Is the dog waiting?': '1. Is there a dog present?\n2. What is the dog doing?\n3. Is the dog waiting?',
#  'Is the dog looking at a tennis ball or frisbee?': '1. Is there a dog in the image?\n2. Is the dog looking at something?\n3. Is there a tennis ball in the image?\n4. Is there a frisbee in the image?\n5. Is the dog looking at a tennis ball?\n6. Is the dog looking at a frisbee?',
#  'Is the sky blue?': '1. Is there a sky?\n2. What color is the sky?',
#  'Is there snow on the mountains?': '1. Are there mountains in the given image?\n2. Is there any substance covering the mountains in the given image?\n3. Is the substance on the mountains white in color?',
#  'What is the white streak?': '1. Is there a streak in the image?\n2. Is the streak white?',
#  'Is the window open?': '1. Is there a window in the given situation?\n2. Is the window in a closed state?',
#  'What color is the toothbrush?': '1. Is there a toothbrush present?\n2. What is the color of the toothbrush?',
#  'What is the child doing?': '1. Is there a child in the given image?\n2. Is the child engaged in any activity?\n3. What action is the child performing?',
#  'Is she brushing?': '1. Is there a person in the given context?\n2. Is the person holding a brush or any brushing tool?\n3. Is the person making brushing movements?\n4. Is the person brushing their hair or something else?',
#  'Is the man smiling?': "1. Is there a man in the image?\n2. Is the man showing any facial expression?\n3. Is the man's facial expression indicative of a smile?",
#  'What is the business man doing in the picture?': '1. Is there a picture?\n2. Is there a business man in the picture?\n3. What is the business man doing?',
#  'Does his tie pair well with his suit?': '1. Is he wearing a tie?\n2. Is he wearing a suit?\n3. What color is his tie?\n4. What color is his suit?\n5. Do the colors of his tie and suit match well together?',
#  'Does the man look happy?': "1. Is there a man in the image? \n2. Does the man have any facial expressions? \n3. Does the man's facial expression indicate happiness?",
#  'Is this photo in color?': '1. Is there a photo?\n2. Is the photo in color?',
#  'Is the man wearing a plain tie?': '1. Is there a man in the image?\n2. Is the man wearing a tie?\n3. Is the tie plain?',
#  'Judging from the dress, was this taken in a Latin American country?': '1. Is there a person wearing a dress in the image?\n2. What does the dress look like?\n3. Are there any identifiable cultural or traditional elements in the dress that can be associated with Latin American countries?\n4. Are there any other visual cues or context in the image that suggest it was taken in a Latin American country?',
#  'What colors are shown in this picture?': '1. Is there a picture provided?\n2. What objects are shown in the picture?\n3. What are the colors of those objects in the picture?',
#  'Are the men on the sidewalk?': 'Expected output:\n1. Is there a sidewalk?\n2. Are there men?\n3. Are the men on the sidewalk?',
#  'Was this photo taken recently?': '1. Is there a photo in the given image?\n2. Was the photo taken in the past?\n3. Is there any indication in the photo that suggests it was taken recently?',
#  'Does the guy have a tattoo?': '1. Is there a guy in the image?\n2. Can we see any visible body parts of the guy?\n3. Is there a body part where a tattoo could potentially be?\n4. Can we see that body part clearly?\n5. Does that body part have a tattoo?',
#  'What is this man riding on?': '1. Is there a man in the image?\n2. Is the man riding something?\n3. What is the man riding on?',
#  "How many tattoos can be seen on this man's body?": "1. Is there a man in the image?\n2. Can tattoos be seen on the man's body? \n3. How many tattoos can be seen on the man's body?",
#  'What color is his hat?': '1. Is there a person in the image?\n2. Is the person wearing a hat?\n3. What is the color of the hat?',
#  "Is the man's visor providing his face enough protection?": "1. Is there a man in the image?\n2. Is the man wearing a visor?\n3. Is the visor providing protection?\n4. Is the visor providing enough protection for the man's face?",
#  'What color is the jacket?': '1. Is there a jacket in the image?\n2. What is the color of the jacket?',
#  'Is the man riding on a dirt path?': '1. Is there a man in the image?\n2. Is the man riding something?\n3. Is there a path in the image?\n4. Is the path made of dirt?\n5. Is the man riding on the path?',
#  'What is the man riding on?': '1. Is there a man in the image?\n2. Is the man riding on something?',
#  'What is on the pillow?': '1. Is there a pillow? \n2. What is on the pillow?',
#  'How many pieces of furniture which are used for sleeping are featured in this picture?': '1. Is there furniture in the picture?\n2. What are the pieces of furniture in the picture?\n3. Are any of the pieces of furniture used for sleeping?\n4. How many pieces of furniture used for sleeping are featured in the picture?',
#  'Are the walls done in a summery color?': '1. Are there walls in the given space? \n2. Have the walls been finished? \n3. What color are the walls? \n4. Is the color of the walls considered summery?',
#  'Is the curtain patterned?': '1. Is there a curtain in the image?\n2. What is the pattern on the curtain?',
#  'What is sitting on the bench?': '1. Is there a bench?\n2. Is there something sitting on the bench?\n3. What is the thing that is sitting on the bench?',
#  'Are the windows the same size?': '1. Are there multiple windows in the given image?\n2. What are the sizes of the windows?\n3. Are the sizes of the windows the same?',
#  'What is this person doing?': '1. Is there a person in the image?\n2. What is the person doing?',
#  'How many people are in this image?': '1. Is there an image?\n2. Are there people in the image?\n3. How many people are in the image?',
#  'Is there a shadow of a tree in the foreground?': '1. Is there a tree in the foreground?\n2. Is there a shadow?\n3. Is the shadow of the tree in the foreground?',
#  'What is the man doing?': "1. Is there a man in the image?\n2. What is the man's activity?",
#  'What color is the sky?': '1. Is there a sky?\n2. What is the color of the sky?',
#  'What is the person wearing?': '1. Is there a person in the given image?\n2. What are the different items of clothing worn by the person?\n3. What is the person wearing specifically?',
#  'Did someone forget his luggage in the snow?': '1. Is there snow in the given image?\n2. Is there any luggage in the given image?\n3. Did someone leave their luggage in the snow?',
#  'What color is his coat?': "1. Is there a person in the image?\n2. Is the person wearing a coat?\n3. Is it a male or female person?\n4. What is the color of the person's coat?",
#  'Is it daytime?': '1. Is there a way to determine the current time?\n2. Can we observe the presence of natural light?\n3. Is the sun visible?\n4. Are there any indicators of daylight, such as open businesses or people being awake?\n5. Is it currently within the usual hours of daylight?\n6. Is the sky bright and blue?\n7. Is the environment well-lit without the use of artificial lighting?\n8. Is it currently daytime?',
#  'What is she holding?': '1. Is there a person in the image?\n2. Is the person female?\n3. Is the person holding something in her hand?',
#  'Is the person wearing a hat?': '1. Is there a person in the image?\n2. Is the person wearing any headgear?\n3. Is the headgear a hat?',
#  'What is the dog riding on?': '1. Is there a dog present?\n2. Is the dog riding on something?\n3. What is the dog riding on?',
#  'Is the dog wearing a collar?': '1. Is there a dog in the given image?\n2. Is the dog wearing anything around its neck?\n3. Is the item the dog is wearing a collar?',
#  'Is it a clear day?': '1. Is there a day?\n2. Is it clear?',
#  'Is there a body of water here?': '1. Is there any water in the given location?\n2. Is the water in a natural form (e.g., a river, lake, ocean)?\n3. Is the water contained within a man-made structure (e.g., a swimming pool, fountain)?\n4. Is the water large enough to be considered a body of water?\n5. Is the body of water visible in the given image/location?',
#  'What is in the water?': '1. Is there water present?\n2. What is the composition of the water?\n3. Are there any living organisms in the water?\n4. Are there any objects or debris in the water?\n5. Are there any chemicals or pollutants in the water?\n6. Are there any natural elements or minerals in the water?\n7. Are there any visible changes or disturbances in the water?',
#  'What does the green light, on the TV, indicate?': '1. Is there a green light? \n2. Is the green light on the TV? \n3. What does the green light indicate?',
#  'Is the light on?': '1. Is there a light in the given context?\n2. Is the light connected to a power source?\n3. Is the power source currently providing electricity?\n4. Is the light switch turned on?',
#  'What room of the house is this?': '1. Is there a house in the image?\n2. Is there a room in the house?\n3. What is the appearance or layout of the room?\n4. Can any specific features or furniture in the room help identify it as a specific type of room in the house?\n5. What room of the house is this?',
#  'What is the size of the TV?': '1. Is there a TV in the given image?\n2. Is the TV visible or partially obstructed?\n3. What is the size of the visible TV?',
#  'Is the room messy?': '1. Is there a room?\n2. What is the condition of the room?\n3. Is the room messy?',
#  'Is this a TV screen?': '1. Is there a screen in the image?\n2. Is the screen being referred to as "this"?\n3. Is the screen a TV screen?',
#  'How big is the TV?': '1. Is there a TV?\n2. How can we define the size of the TV? (e.g. diagonal length, width, height)\n3. What are the dimensions of the TV? (e.g. diagonal length, width, height)',
#  'What companion object to the TV can be seen in the bottom right of the picture?': 'Expected output: \n1. Is there a TV in the picture? \n2. What objects are located in the bottom right of the picture? \n3. Is there a companion object to the TV in the bottom right of the picture? \n4. What is the companion object to the TV in the bottom right of the picture?',
#  'What is the small computer on the left called?': '1. Is there a computer on the left?\n2. Is the computer small?\n3. What is the name of the small computer on the left?',
#  'What is above the TV?': '1. Is there a TV?\n2. What is the position of the TV?\n3. Is there anything above the TV?',
#  'What is on the display?': '1. Is there a display?\n2. What is on the display?',
#  'Is there a laptop in the image?': '1. Is there an image?\n2. Is there an object in the image?\n3. Is the object a laptop?',
#  'Is it a monitor or a screen projection?': '1. Is there a display device present?\n2. Is the display device a monitor?\n3. Is the display device a screen projection?',
#  'What is on the TV screen?': '1. Is there a TV in the image?\n2. Is the TV screen visible?\n3. What is on the TV screen?',
#  'What is the title of the presentation in the picture?': '1. Is there a presentation in the picture?\n2. Is there a title displayed in the presentation?\n3. What is the content of the title displayed in the presentation?',
#  'What color is the bear?': '1. Is there a bear?\n2. What is the color of the bear?',
#  'Is the animal a mammal?': '1. Is there an animal present?\n2. What type of animal is it?\n3. Does the animal have hair or fur?\n4. Does the animal give birth to live young?\n5. Does the animal nurse its young with milk?\n6. Is the animal warm-blooded?\n7. Does the animal have a backbone?\n8. Does the animal have lungs and breathe air?\n9. Is the animal a mammal?',
#  'What is this?': '1. Is there an object in the given image?\n2. What is the appearance of the object?\n3. Can we identify the category or type of the object?\n4. Can we determine the specific name or label of the object?',
#  'Are there rocks in the picture?': '1. Is there a picture?\n2. Are there objects in the picture?\n3. Are there rocks among the objects in the picture?',
#  'Has the sheep recently been shaved?': "1. Is there a sheep in the image?\n2. Is the sheep's appearance different from the previous image?\n3. Has the sheep's wool been removed or trimmed?",
#  'How many sheeps are this?': '1. Are there sheep in the image?\n2. How many sheep are there in the image?',
#  'Are there three sheep?': '1. Are there animals in the scene?\n2. Are there sheep in the scene?\n3. How many sheep are there in the scene?\n4. Are there three sheep in the scene?',
#  'What is the man playing?': 'Expected output: 1. Is there a man in the image? 2. Is the man playing any instrument? 3. What instrument is the man playing?',
#  'Is the man having a good time?': '1. Is there a man in the given scenario?\n2. What is the man doing?\n3. Does the man appear to be happy?\n4. Is he engaged in any activities or conversations that may indicate a good time?',
#  'What does the man have on his face?': "1. Is there a man in the image?\n2. What is on the man's face?",
#  'What is in front of the giraffes?': 'Expected output: \n1. Are there giraffes in the image? \n2. Are there objects in front of the giraffes? \n3. What are the objects in front of the giraffes?',
#  'What do these giraffes have in common?': '1. Are there multiple giraffes in the given image?\n2. What are the characteristics of each giraffe in the image?\n3. Do the giraffes have similar patterns on their fur?\n4. Do the giraffes have similar body shapes?\n5. Do the giraffes have similar heights?\n6. Do the giraffes have similar neck lengths?\n7. Do the giraffes have similar coloration on their bodies?\n8. Do the giraffes have similar horn shapes?\n9. Do the giraffes have similar tail lengths?\n10. Do the giraffes have similar ear shapes?\n11. Do the giraffes have similar leg lengths?\n12. Do the giraffes have similar eye shapes?\n13. Do the giraffes have similar tongue lengths?',
#  'Could this photo be from a zoo?': '1. Is there a photo?\n2. What does the photo depict?\n3. Are there any animals in the photo?\n4. Are the animals typically found in a zoo?\n5. Are there any recognizable zoo elements in the photo (e.g., cages, signage)?\n6. Are there any distinctive features that suggest the photo was taken at a zoo? \n7. Could the photo be from a zoo?',
#  'Are the animals eating?': '1. Are there animals in the given scenario?\n2. What are the animals doing?\n3. Are the animals eating?',
#  'Where is the giraffe?': '1. Is there a giraffe in the given image?\n2. If there is a giraffe, what is its location?',
#  'Is there a zebra?': '1. Is there an image or visual context provided?\n2. Is there any mention or indication of the presence of an animal?\n3. Is there any mention or indication of the presence of a zebra specifically?',
#  'What is the giraffe standing behind?': '1. Is there a giraffe in the image?\n2. Is the giraffe standing behind something?\n3. What is the object that the giraffe is standing behind?',
#  'Is the giraffe eating the tree?': '1. Is there a giraffe in the image?\n2. Is the giraffe eating something?\n3. Is there a tree in the image?\n4. Is the giraffe near the tree?\n5. Is the giraffe interacting with the tree?\n6. Is the giraffe eating the tree?',
#  'Are both giraffes standing?': '1. Are there giraffes in the image?\n2. How many giraffes are in the image?\n3. Are both giraffes standing?',
#  'Are they at a zoo?': '1. Is there a group of people in the given image?\n2. Are there any animals in the given image?\n3. Is there a specific location or environment shown in the given image?\n4. Is there any indication of cages, enclosures, or exhibits in the given image?\n5. Is there any signage or visual cues that suggest a zoo setting?\n6. Are there any specific species of animals typically found in a zoo?\n7. Is there any evidence of zoo infrastructure or facilities, such as ticket booths or fences?\n8. Are there any staff members or visitors wearing clothing associated with zoos?\n9. Is there any text or labels in the image that mention a zoo?\n10. Based on the overall visual context, does the image resemble a typical zoo environment?',
#  'What is on the ground next to the giraffe on the right?': '1. Is there a giraffe in the image?\n2. Is the giraffe positioned on the right side?\n3. Is there anything next to the giraffe on the right?\n4. Is there something on the ground?\n5. What is on the ground next to the giraffe on the right?',
#  'Are some of the trees dead?': '1. Are there trees in the given area?\n2. Are there any signs of decay or wilting on the trees?\n3. Are there any trees with brown or discolored leaves?\n4. Are there any trees with no leaves at all?\n5. Are there any trees with broken or fallen branches?\n6. Are there any trees that appear unhealthy or dying?\n7. Are there any trees that have fallen over completely?',
#  'Are any of the animals eating?': '1. Are there any animals in the scene?\n2. Is there any food present in the scene?\n3. Are any of the animals near the food?\n4. Are any of the animals showing signs of eating?',
#  'Is the giraffe in the shade?': '1. Is there a giraffe in the image?\n2. Is there any shade in the image?\n3. Is the giraffe located in the shaded area?\n4. Is the giraffe in the shade?',
#  'Are these giraffes living free range?': '1. Are there giraffes in the given image?\n2. Are the giraffes living in a confined space?\n3. Are the giraffes living in a controlled environment?\n4. Are the giraffes living in a natural habitat?\n5. Are the giraffes living in an open area?\n6. Are the giraffes able to roam freely?\n7. Are the giraffes living free range?',
#  'How many giraffes are there?': '1. Are there any giraffes present?\n2. If there are giraffes present, how many are there?',
#  'Is there a rock near the giraffe?': '1. Is there a giraffe in the given image?\n2. Is there a rock in the given image?\n3. Is the rock near the giraffe?',
#  'How many animals are in this photo?': '1. Is there a photo?\n2. Are there any animals in the photo?\n3. How many animals are there in the photo?',
#  'Why is the man on the street?': '1. Is there a man on the street?\n2. Why is the man on the street?',
#  'How is the man sitting?': '1. Is there a man in the given image?\n2. Is the man sitting?\n3. How is the man sitting?',
#  'What does the word in the upper-left corner, behind the window, translate to in English?': 'Expected output:\n1. Is there a word in the upper-left corner?\n2. Is there a window?\n3. Is the word behind the window?\n4. What is the word in the upper-left corner?\n5. Can the word be translated to English?',
#  'How many people are on the boat?': '1. Is there a boat in the image?\n2. Are there people on the boat?\n3. How many people are on the boat?',
#  'What color are the leaves?': '1. Are there leaves in the given image?\n2. What is the color of the leaves?',
#  'What type of watercraft is that?': '1. Is there a watercraft in the image?\n2. What are the distinguishing features of the watercraft?\n3. What are the different types of watercraft?\n4. Does the watercraft match the features of any specific type?\n5. What type of watercraft does it belong to?',
#  'Where are the two blue coolers?': '1. Are there two blue coolers in the given scenario?\n2. Where are the coolers located?',
#  'What kind of room is this?': '1. Is there any furniture in the room?\n2. Are there any decorative elements in the room?\n3. What is the color of the walls in the room?\n4. What is the shape of the room?\n5. What is the size of the room?\n6. What is the purpose of the room?\n7. What is the style of the room?\n8. What is the lighting like in the room?\n9. What is the flooring material in the room?\n10. What is the overall atmosphere or ambiance of the room?',
#  'Are they moving?': '1. Who are "they" referring to?\n2. Is there any indication of movement?\n3. Are there any visible changes in position or motion?\n4. Are there any visible changes in facial expressions or body language?\n5. Is there any evidence of dynamic activity or motion blur in the image or video?\n6. Are there any visible signs of motion in the background or surrounding objects?\n7. Are there any visible indications of motion in the limbs or body parts of the subjects?\n8. Is there any audible evidence of movement, such as footsteps or rustling sounds?\n9. Are there any contextual clues or information suggesting movement?\n10. Can we conclude that they are indeed moving based on the available evidence and observations?',
#  'What color is the umbrella?': '1. Is there an umbrella in the given image?\n2. What is the color of the umbrella?',
#  'Is this man angry?': "1. Is there a man in the image?\n2. What is the expression on the man's face?\n3. Does the man's expression indicate anger?",
#  'Which hand holds the umbrella?': '1. Is there an umbrella in the image?\n2. Are there hands visible in the image?\n3. Which hand is holding something?\n4. Is the hand holding the umbrella visible?\n5. Which hand is holding the umbrella?',
#  'Are there flowers in the vase?': '1. Is there a vase?\n2. Are there flowers in the vase?',
#  'What is the vase sitting on?': '1. Is there a vase in the image?\n2. Is the vase sitting on something?',
#  'Is the sun to the right or left of this flower?': '1. Is there a sun in the image?\n2. Is there a flower in the image?\n3. Is the sun positioned to the right of the flower?\n4. Is the sun positioned to the left of the flower?',
#  'Are the flowers open?': '1. Are there flowers in the given image?\n2. Are the flowers in a closed state?\n3. Are there any visible signs of blooming on the flowers?',
#  'What color is the vase?': '1. Is there a vase in the given image?\n2. What is the color of the vase?',
#  'Are all the flowers white?': '1. Are there any flowers?\n2. What is the color of the flowers?',
#  'Is the man standing on both foot?': '1. Is there a man in the image?\n2. Is the man standing?\n3. How many feet does the man have?\n4. Is the man standing on one foot or both feet?',
#  'Was this picture likely taken recently?': '1. When was the picture taken?\n2. What are the visual clues in the picture that can indicate the time it was taken?\n3. Are there any objects or elements in the picture that can give a hint about the recentness of the picture?\n4. Are there any people or their clothing styles that can suggest the picture was taken recently?\n5. Are there any technological devices or gadgets visible in the picture that can indicate the picture was taken recently?',
#  "Do the gentleman's socks match his shoes and belt?": "1. Is there a gentleman in the given image?\n2. Is the gentleman wearing socks?\n3. What is the color of the gentleman's socks?\n4. Is the gentleman wearing shoes?\n5. What is the color of the gentleman's shoes?\n6. Is the gentleman wearing a belt?\n7. What is the color of the gentleman's belt?\n8. Do the color of the gentleman's socks, shoes, and belt match?",
#  'What is the zebra eating?': '1. Is there a zebra in the image?\n2. Is the zebra eating something?',
#  'Are the zebras facing the same direction?': '1. Are there zebras in the image?\n2. How many zebras are there?\n3. Are the zebras facing a direction?\n4. What direction are the zebras facing?\n5. Are the zebras facing the same direction?',
#  'What is the tree covered with?': '1. Is there a tree in the given image?\n2. Is the tree covered with something?\n3. What is the tree covered with?',
#  'Is this a horse?': '1. Is there an image or object being referred to? \n2. What is the subject of the image or object? \n3. Is the subject an animal? \n4. Is the subject specifically a horse?',
#  'What is the animal eating?': '1. Is there an animal present?\n2. Is the animal eating something?\n3. What is the animal eating?',
#  'How old is animal?': '1. Is the animal alive?\n2. Is the animal a specific species or type?\n3. Does the age of the animal refer to its current age or its lifespan?\n4. If referring to its current age, how can we determine the age of the animal?',
#  "Are they drinking wine at the child's party?": "1. Is there a child's party happening?\n2. Are they drinking anything at the party?\n3. Is the drink they are consuming wine?",
#  'Is the man wearing glasses?': '1. Is there a man in the image?\n2. Is the man wearing anything on his face?\n3. Are those things on his face glasses?',
#  'What is the man holding?': '1. Is there a man in the image?\n2. Is the man holding something?\n3. What is the object that the man is holding?',
#  'What is the man cutting?': '1. Is there a man in the image?\n2. What is the man doing?\n3. Is the man cutting something?',
#  'What is the fruit?': '1. Is there an object in the image?\n2. Is the object a fruit?',
#  'Is this a good dessert?': '1. What is the dessert in question?\n2. What are the criteria for a dessert to be considered "good"?\n3. Does the dessert meet those criteria?',
#  'What is the name of the type of person that would make this food?': '1. What kind of food is being referred to?\n2. What are the ingredients used in making this food?\n3. What are the cooking techniques involved in making this food?\n4. What is the cultural or regional origin of this food?\n5. What are the specific characteristics or flavors associated with this food?\n6. Is there a specific name or term used to describe the person who makes this food?',
#  'What type of ice cream is on the plate?': '1. Is there a plate in the image?\n2. Is there ice cream on the plate?\n3. What type of ice cream is on the plate?',
#  'How many people are wearing shorts in the forefront of this photo?': '1. Is there a photo?\n2. Is there a forefront in the photo?\n3. Are there people in the forefront?\n4. Are the people wearing shorts?',
#  'Is this an indoor or outdoor photo?': '1. Is there a photo?\n2. Is the photo taken indoors?\n3. Is the photo taken outdoors?',
#  'Are those kites in the air?': '1. Are there objects in the air?\n2. Are there multiple objects in the air?\n3. Do the objects resemble kites?\n4. Are the objects actually kites?',
#  'Is this a hot dog?': '1. Is there an object in the image?\n2. What does the object look like?\n3. Is the object a hot dog?',
#  'What color is the napkin?': '1. Is there a napkin in the given context?\n2. What is the color of the napkin?',
#  'Is there ketchup on the hot dog?': '1. Is there a hot dog?\n2. Is there ketchup?\n3. Is the ketchup on the hot dog?',
#  'Has this hot dog been grilled?': '1. Is there a hot dog? \n2. Has the hot dog been cooked? \n3. Has the hot dog been grilled?',
#  'Have you tried a hot dog like this before?': '1. Have you tried a hot dog before?\n2. Is the hot dog in question similar to the hot dog you have tried before?',
#  "What's missing from this hot dog?": '1. Is there a hot dog in the given image?\n2. What are the components of a typical hot dog?\n3. Are any of those components missing from the hot dog in the image?',
#  'What is the hog dog sitting on?': '1. Is there a hot dog in the given image?\n2. Is the hot dog sitting on something?\n3. What is the hot dog sitting on?',
#  'Is this a toy-sized truck?': '1. Is there a truck in the image?\n2. What is the size of the truck?\n3. Is the size of the truck smaller than normal?\n4. Is the truck a toy-sized truck?',
#  'What is the sky full of?': '1. Is there a sky?\n2. Is the sky full of something?',
#  'Where are the trucks?': '1. Are there any trucks present?\n2. How many trucks are there?\n3. Are the trucks inside or outside?\n4. If inside, which room or area are the trucks located in?\n5. If outside, where specifically are the trucks located?',
#  'What is the color of the carpet?': '1. Is there a carpet in the given image?\n2. What is the color of the carpet?',
#  'Is there a carpet on the floor?': '1. Is there a floor in the given image?\n2. Is there a carpet in the given image?\n3. Is the carpet on the floor?',
#  'What color is the refrigerator?': '1. Is there a refrigerator present in the given context?\n2. What is the color of the refrigerator?',
#  'What is this device?': '1. Is there an image or description of the device provided?\n2. Is there any specific context or category mentioned for the device?\n3. Can any visual or physical characteristics of the device be identified?\n4. Are there any unique features or functions mentioned for the device?\n5. Can any additional information about the device be gathered from the given context?',
#  'Is this plane landing?': '1. Is there a plane in the given image?\n2. Is the plane in motion?\n3. Is the plane descending?\n4. Is the plane approaching a runway?\n5. Is there a runway visible in the image?\n6. Is the runway suitable for landing?\n7. Is the plane aligned with the runway?\n8. Is the landing gear deployed?\n9. Is the plane at a low altitude?\n10. Is the plane in the correct landing configuration?\n11. Is the plane making a smooth descent?\n12. Is there any indication of a landing, such as smoke or dust?\n13. Is the plane showing any signs of landing, such as flaps or spoilers?\n14. Is the plane touching down on the runway?',
#  'What color is the plane?': '1. Is there a plane in the image?\n2. What is the color of the plane?',
#  'What shape are the windows on the side of the plane?': '1. Are there windows on the side of the plane?\n2. What is the shape of the windows on the side of the plane?',
#  'Is the plane taking off?': "1. Is there a plane in the given image?\n2. Is the plane in motion?\n3. Is the plane moving upwards?\n4. Is the plane's landing gear retracted?\n5. Are there any signs of acceleration or lift-off?\n6. Is the plane leaving the ground?\n7. Is the angle of the plane's ascent increasing?\n8. Is the plane gaining altitude?\n9. Is the plane taking off?",
#  'Are these airliners?': '1. Are there objects in the given image?\n2. Are there multiple objects in the given image?\n3. Are the objects in the image airplanes?\n4. Are the objects in the image specifically airliners?',
#  'How many planes are in the picture?': '1. Is there a picture?\n2. Are there any objects in the picture?\n3. Are there any objects that resemble planes in the picture?\n4. How many objects that resemble planes are in the picture?',
#  'Are this cargo planes?': '1. Are there any planes in the given image?\n2. What type of planes are in the image?\n3. Are the planes cargo planes?',
#  'Is this bear a normal size?': '1. Is there a bear in the image?\n2. What is the size of the bear?\n3. Is the size of the bear considered normal?',
#  'What is the website on the sign?': '1. Is there a sign in the image?\n2. Is there text on the sign?\n3. Is the text on the sign a website?\n4. What is the text on the sign?',
#  'What is the bear called?': '1. Is there a bear in the image?\n2. What is the name of the bear?',
#  'Is there a flower arrangement on the lawn?': '1. Is there a lawn?\n2. Is there an arrangement?\n3. Is it a flower arrangement?\n4. Is the flower arrangement on the lawn?',
#  'What color horse is closer to the camera?': '1. Are there multiple horses in the image?\n2. Is there a horse closer to the camera?\n3. What color is the horse closer to the camera?',
#  'Are they playing polo?': '1. Is there a group of people in the image?\n2. Are they holding long sticks?\n3. Are they riding horses?\n4. Is there a ball in the image?\n5. Are they hitting the ball with the sticks?\n6. Is the game being played in an open field?\n7. Are there goalposts or a designated playing area?\n8. Are there any specific markings on the field indicating a polo match?\n9. Are there any referees or officials present?\n10. Are the players wearing polo attire or uniforms?',
#  'How many trees are in this photo?': '1. Is there a photo?\n2. Are there trees in the photo?\n3. How many trees are in the photo?',
#  'What type of tree is the man standing next to?': 'Expected output: \n1. Is there a man in the image? \n2. Is the man standing next to a tree? \n3. What type of tree is the man standing next to?',
#  'Is this man reading a cell phone screen?': '1. Is there a man in the image?\n2. Is the man reading something?\n3. Is the man holding a cell phone?\n4. Is the cell phone screen visible?\n5. Is the man reading the cell phone screen?',
#  'What pattern is on the pants?': 'Expected output: \n1. Is there a pair of pants in the image?\n2. Is there a pattern on the pants?',
#  'What sport is this person playing?': '1. Is there a person in the image?\n2. Is the person playing a sport?\n3. What sport is the person playing?',
#  'What is the position of the player behind the batter called?': '1. Is there a player behind the batter?\n2. What is the position of the player behind the batter called?',
#  "What color is the girl's shirt?": "1. Is there a girl in the image?\n2. Is the girl wearing a shirt?\n3. What color is the girl's shirt?",
#  'What are they drinking?': '1. Are there multiple people in the image?\n2. Are they holding drinks?\n3. What type of drinks are they holding?\n4. Is there a specific drink that stands out or is different from the others?\n5. What are the ingredients or components of that specific drink?\n6. Is there any other drink that is different from the rest?\n7. What are the ingredients or components of that other drink?\n8. Are there any other drinks present?\n9. What are the ingredients or components of those other drinks?',
#  'What brand of beer is visible?': '1. Is there a beer visible in the given context?\n2. What are the different brands of beer that could be potentially visible?\n3. Is the brand of beer visible in the given context recognizable?\n4. What is the brand of beer that is visible?',
#  'Where is Brooklyn Avenue?': '1. Is there a street named Brooklyn Avenue?\n2. In which city is Brooklyn Avenue located?',
#  'Which direction is Brooklyn Ave?': '1. Is there a location called Brooklyn Ave?\n2. Is there a map or reference point available to determine the direction of Brooklyn Ave?',
#  'Is there a stop sign in the picture?': '1. Is there a picture?\n2. Is there an object resembling a stop sign in the picture?',
#  "What logo is on the man's shirt?": "1. Is there a man in the image?\n2. Is the man wearing a shirt?\n3. What logo is on the man's shirt?",
#  'Is the man unhappy?': '1. Is there a man in the given context?\n2. Is the man showing any signs of unhappiness?',
#  'Are the men going to share the bananas?': '1. Are there men present?\n2. Are there any bananas present?\n3. Are the men holding the bananas?\n4. Are the men discussing the bananas?\n5. Are the men indicating a willingness to share the bananas?',
#  'What color are the flowers?': '1. Are there flowers in the image?\n2. What is the color of the flowers?',
#  'What colors are the flowers?': '1. Are there any flowers in the given image?\n2. How many flowers are there in the image?\n3. What are the colors of the flowers?',
#  'How many flowers are painted on the vase?': '1. Is there a vase in the image?\n2. Are there flowers on the vase?\n3. Are the flowers painted on the vase?\n4. How many flowers are painted on the vase?',
#  'Do the painted flowers match the real ones?': '1. Are there painted flowers?\n2. Are there real flowers?\n3. Do the painted flowers and real flowers have the same design?\n4. Do the painted flowers and real flowers have the same colors?',
#  'Where is the bird?': '1. Is there a bird in the given image?\n2. If there is a bird, what is its location?',
#  'Will the birds go into the water?': '1. Are there birds present?\n2. Is there water present?\n3. Can birds go into water?',
#  'What direction is the bird looking?': '1. Is there a bird in the given image?\n2. Is the bird facing a specific direction?\n3. What is the direction that the bird is facing?',
#  'Is this bird afraid of the ledge?': '1. Is there a bird in the given image?\n2. Is there a ledge in the given image?\n3. Is the bird located near the ledge?\n4. Does the bird display any signs of fear or anxiety?\n5. Is the bird exhibiting any behavior that suggests it is afraid of the ledge?',
#  'What time of day is it?': 'Expected output: \n1. Can we determine the time of day based on the given information?\n2. Is there any indication of natural light in the image?\n3. Is there a clock or any other time-displaying device visible in the image?\n4. Is there a window or any other source of external light visible in the image?\n5. Is there any artificial light source visible in the image?\n6. Is there any other contextual information or clues that could suggest the time of day?',
#  'How many elephants are in the water?': '1. Is there water in the given image?\n2. Are there any animals in the given image?\n3. Are there any elephants in the given image?\n4. Are the elephants in the water?\n5. How many elephants are in the water?',
#  'How many tails can you see in this picture?': '1. Is there an image?\n2. Can you see any tails in the image?\n3. How many tails can you see in the image?',
#  'How many tusks are visible?': '1. Are there any tusks in the given image?\n2. Are there any objects obstructing the view of the tusks?\n3. How many tusks are not obstructed in the image?\n4. How many tusks are visible in the image?',
#  'What is this animal?': '1. Is there an animal in the image?\n2. What does the animal look like?\n3. What are the distinguishing features of the animal?\n4. Can we identify the species of the animal?',
#  'What color is the animal?': '1. Is there an animal?\n2. What is the color of the animal?',
#  'What type of plane is this?': "1. Is there a plane in the image?\n2. What are the distinguishing features of the plane?\n3. What are the characteristics of the plane's wings?\n4. What are the characteristics of the plane's engines?\n5. What are the characteristics of the plane's tail?\n6. What are the characteristics of the plane's fuselage?\n7. What is the overall shape and size of the plane?\n8. What is the purpose or usage of the plane?\n9. What is the specific type or model of the plane?",
#  'Are the mountains high?': '1. Are there mountains in the given scenario?\n2. How can we define the height of the mountains?\n3. Can we measure the height of the mountains?\n4. Based on the measurement, are the mountains considered high or not?',
#  'What color are the seats?': '1. Are there seats in the given context?\n2. How many seats are there?\n3. What is the color of each seat?',
#  'Is there a person standing in front of the television?': '1. Is there a television?\n2. Is there a person?\n3. Is the person standing?\n4. Is the person standing in front of the television?',
#  'Where is the mirror?': '1. Is there a mirror present in the given environment? \n2. If there is a mirror, is it visible or hidden? \n3. If the mirror is visible, where is it located? \n4. If the mirror is hidden, is there any indication or clue about its location? \n5. If there is a clue about its location, where does the clue suggest the mirror might be?',
#  'Is there enough room under the armchairs for a cat to hide?': '1. Are there armchairs in the room?\n2. Is there enough space underneath the armchairs?\n3. Can a cat fit under the armchairs?\n4. Is there a cat in the room?\n5. Can the cat hide under the armchairs?',
#  'Who made the cock?': '1. Is there a cock in question?\n2. Who is the creator or maker of the cock?',
#  'Are there numbers on the clock face?': '1. Is there a clock in the image? \n2. Is there a clock face on the clock? \n3. Are there numbers on the clock face?',
#  'Is there a big tree behind the clock?': '1. Is there a clock?\n2. Is the clock positioned in front of anything?\n3. Is there a tree behind the clock?\n4. Is the tree big?',
#  'What is in the picture?': '1. Is there an image? \n2. What are the objects or subjects in the image?',
#  'What time is the clock showing?': '1. Is there a clock in the image?\n2. Is the clock showing the current time?\n3. What time is the clock showing?',
#  'What are the vases sitting on?': '1. Are there vases in the given image? \n2. What are the vases? \n3. Are the vases sitting on something? \n4. If yes, what are the vases sitting on?',
#  'How many trees on the table?': '1. Is there a table?\n2. Are there trees on the table?\n3. How many trees are there on the table?',
#  'How many horns are in the picture?': '1. Is there a picture?\n2. Are there any objects in the picture?\n3. Are there any animals in the picture?\n4. Are there any animals with horns in the picture?\n5. How many animals with horns are in the picture?',
#  'What color is the middle vase?': '1. Is there a vase in the image?\n2. How many vases are there in the image?\n3. Is one of the vases positioned in the middle?\n4. What is the color of the middle vase?',
#  'What is the table made of?': '1. Is there a table in the given image?\n2. What is the material of the table?',
#  'What kind of trees are on the table?': '1. Is there a table?\n2. Are there trees on the table?\n3. What kind of trees are on the table?',
#  'Is this a wedding?': '1. What is "this" referring to?\n2. Is there a gathering of people in the image?\n3. Are the people dressed in formal attire?\n4. Is there a bride and groom present?\n5. Are there decorations typically associated with weddings present?\n6. Is there any indication of a ceremony or wedding rituals taking place?\n7. Is there a wedding cake or any other wedding-related elements present?\n8. Is there any evidence of guests, such as seating arrangements or invitations?\n9. Are there any other events or occasions that this gathering could be related to?',
#  'What is the green stuff on this pizza?': '1. Is there a pizza in the given image?\n2. Is there something green on the pizza? \n3. What is the green stuff on the pizza?',
#  'Does the crust look burnt?': '1. Is there a crust?\n2. What does the crust look like?\n3. Does the crust have a burnt appearance?',
#  'Is it thick or thin crust?': '1. Is there a crust?\n2. What is the thickness of the crust?',
#  'Does this pizza have a deep dish crust?': '1. Is there a pizza in the image?\n2. What type of crust does the pizza have?\n3. Does the pizza have a deep dish crust?',
#  'Is the banana freshly peeled?': '1. Is there a banana in the given image?\n2. Is the banana peeled?\n3. Is the banana freshly peeled?',
#  'Is the banana closed?': '1. Is there a banana?\n2. Is the banana open or closed?',
#  'What is the orange thing?': '1. Is there an orange thing?\n2. Can you provide more context or description about the orange thing?',
#  'Does this photo show train tracks?': '1. Is there a photo?\n2. Does the photo show anything?\n3. Does the photo show tracks?\n4. Does the photo show train tracks?',
#  'Does this train work?': "1. Is there a train?\n2. What train is being referred to?\n3. Is the train in question operational?\n4. Does the train have any mechanical issues?\n5. Is the train currently in use?\n6. Is the train able to transport passengers or goods?\n7. Has the train been tested for functionality?\n8. Are there any known issues with the train's operation?",
#  'Is this train headed towards or from the orange building?': '1. Is there a train in the given image?\n2. Is there an orange building in the given image?\n3. Is the train moving?\n4. Is the train currently closer to the orange building or farther away from it?\n5. Is the train moving towards the orange building?\n6. Is the train moving away from the orange building?\n7. Is the train currently located in front of the orange building?\n8. Is the train currently located behind the orange building?',
#  'How many Giraffes are in this image?': '1. Is there an image?\n2. Are there any animals in the image?\n3. Are there any giraffes in the image?\n4. How many giraffes are in the image?',
#  'What is the giraffe eating?': '1. Is there a giraffe in the image?\n2. What is the giraffe doing?\n3. Is the giraffe eating something?',
#  'Are the giraffes under the trees?': '1. Are there giraffes in the given image?\n2. Are there trees in the given image?\n3. Are the giraffes positioned below the trees?',
#  'Are there 3 elephants?': '1. Are there any animals in the given image?\n2. Are there any elephants in the given image?\n3. How many elephants are there in the given image?\n4. Are there 3 elephants in the given image?',
#  'Are all of the elephants full grown?': '1. Are there elephants present?\n2. How many elephants are present?\n3. Are any of the elephants not full grown?\n4. Are all of the elephants full grown?',
#  'Are the elephants in the jungle?': '1. Is there a jungle?\n2. Are there elephants?\n3. Are the elephants in the jungle?',
#  "What is on the woman's neck?": "1. Is there a woman in the image?\n2. Is there something on the woman's neck?",
#  'Is the woman eating the pizza?': '1. Is there a woman in the image?\n2. Is there a pizza in the image?\n3. Is the woman interacting with the pizza?\n4. Is the woman holding or touching the pizza?\n5. Is the woman putting the pizza in her mouth or taking a bite?',
#  'How many stairs are there?': '1. Are there any stairs?\n2. How many stairs are there?',
#  'Where is the sink located?': '1. Is there a sink in the given location?\n2. What is the location being referred to?\n3. Is there a specific sink that is being referred to?\n4. If yes, what is the specific sink?\n5. Where is the specific sink located?',
#  'Where is the soap?': '1. Is there a soap?\n2. Where is the soap?',
#  'What color is the window frame?': '1. Is there a window in the given image?\n2. Is there a frame around the window?\n3. What is the color of the window frame?',
#  'What item is folded up and sitting on the edge of the shower stall?': '1. Is there a shower stall in the image?\n2. Is there an item sitting on the edge of the shower stall?\n3. Is the item folded up?\n4. What is the item sitting on the edge of the shower stall?',
#  'What pattern is on the shower curtain?': '1. Is there a shower curtain in the image?\n2. What is the pattern on the shower curtain?',
#  'What are the colors of the countertop?': '1. Is there a countertop?\n2. How many colors are there on the countertop?\n3. What are the colors of the countertop?',
#  'Are there any reflections in this picture?': '1. Is there a picture?\n2. Are there any objects in the picture?\n3. Are there any reflective surfaces in the picture?\n4. Are there any reflections in the picture?',
# ...
#  'What is in the jug?': '1. Is there a jug present?\n2. What is inside the jug?',
#  'What is the name of this crusted food?': '1. Is there crusted food in the image?\n2. What does the crusted food look like?\n3. Does the crusted food have a specific shape or form?\n4. Is there a known name for this type of crusted food?',
#  'What color are the items on the truck?': '1. Is there a truck in the image?\n2. Are there items on the truck?\n3. What are the colors of the items on the truck?',
#  'Is the writing in French?': '1. Is there any writing in the given context? \n2. What language is the writing in? \n3. Is the language of the writing French?',
#  'Is this a traveling circus?': '1. Is there a circus present?\n2. Is there a performance happening?\n3. Are there performers present?\n4. Is there a tent or a big top?\n5. Is the tent or big top mobile?\n6. Is the circus moving from one location to another?',
#  'What animal is on the flatbed?': '1. Is there an animal on the flatbed? \n2. What is the animal on the flatbed?',
#  'What is the floor made out of?': '1. Is there a floor in the given context?\n2. What materials are present in the context?\n3. Is there a specific material that is being referred to as "the floor"?\n4. What is the material of "the floor" being referred to?',
#  'What do you use the stove for?': '1. Is there a stove present? \n2. What are the possible uses of a stove? \n3. What are the common uses of a stove? \n4. What are the different types of stoves? \n5. What are the specific uses of each type of stove?',
#  'What is the batter wearing on his ankles?': '1. Is there a batter in the given image?\n2. What is the batter wearing on his ankles?',
#  'Are there long lenses?': '1. Are there lenses in the given context?\n2. Are the lenses long?',
#  'What is the crouching man in the mask called?': '1. Is there a crouching man in the image?\n2. Is the crouching man wearing a mask?\n3. What is the name of the crouching man in the mask?',
#  'How many people are standing next to each other?': '1. Are there people in the image?\n2. Are the people standing?\n3. Are the people standing next to each other?\n4. How many people are standing next to each other?',
#  'What are the two women carrying?': 'Expected output: \n\n1. Are there two women in the image?\n2. Are the two women carrying something?\n3. What are the two women carrying?',
#  'What are these people holding?': '1. Are there people in the image?\n2. Are the people holding something?\n3. What are the people holding?',
#  'How many rackets?': '1. Are there any rackets?\n2. How many rackets are there?',
#  'How many people are in this photo?': '1. Is there a photo?\n2. Are there people in the photo?\n3. How many people are in the photo?',
#  'What is the woman wearing on her neck?': '1. Is there a woman in the image?\n2. Is the woman wearing something on her neck?',
#  'Is everyone wearing long sleeves?': '1. Is there a group of people? \n2. Is anyone in the group wearing sleeves? \n3. Is anyone in the group wearing long sleeves? \n4. Are all the people in the group wearing long sleeves?',
#  'What sports are they playing?': '1. Are there people in the image?\n2. Are the people engaged in physical activity?\n3. Are they holding any equipment or wearing any specific gear?\n4. Are there any specific actions or movements being performed?\n5. Are there any specific markings or elements in the surroundings indicating a particular sport?\n6. Are there any specific rules or characteristics of the sport being followed?\n7. What sports are commonly played in the given context or location?',
#  'What is the approximate time period of this photo?': '1. Is this a photo?\n2. Is there a time period associated with this photo?',
#  'How many girls are in the picture?': '1. Is there a picture?\n2. Are there any people in the picture?\n3. Are there any girls in the picture?\n4. How many girls are in the picture?',
#  'Which two are actually playing?': 'Expected output: 1. Are there multiple people in the scene? 2. Are any of the people in the scene engaged in an activity that can be considered playing? 3. Which two people in the scene are engaged in playing?',
#  'Are the woman wearing short dresses?': '1. Is there a woman in the image?\n2. Is the woman wearing a dress?\n3. Is the dress short?',
#  'Is the lady smiling?': "1. Is there a lady in the image?\n2. Is the lady showing any facial expression?\n3. Is the lady's facial expression a smile?",
#  'Do they play for Red Sox?': '1. Who are "they" referred to in the question?\n2. Do "they" play a sport?\n3. Is the sport they play baseball?\n4. Is "Red Sox" the name of a baseball team?\n5. Do "they" play for the Red Sox?',
#  'What three letter word, best describes the liquid container on the ground between the two people?': '1. Is there a liquid container on the ground?\n2. Are there two people?\n3. Is the liquid container between the two people?\n4. What is the three-letter word that best describes the liquid container on the ground between the two people?',
#  'What does the wall say on the far left?': '1. Is there a wall in the image?\n2. Is the wall on the left side?\n3. Is there any text or writing on the wall?\n4. What does the writing on the wall say?',
#  'Is this a mixed race group?': '1. Are there multiple people in the group?\n2. Do the people in the group have different racial backgrounds?\n3. Is there any evidence or indication of mixed race heritage among the individuals in the group?',
#  'Are these people getting reading to go play sports?': '1. Are there people in the image?\n2. What are the people doing?\n3. Are the people preparing for something?\n4. Are they preparing to go play sports?',
#  'Is there any females?': '1. Is there anyone in the given group or context?\n2. Are there any females in the group or context?',
#  "How many people don't have a skateboard?": "1. How many people are there?\n2. How many people have a skateboard?\n3. Subtract the number of people with a skateboard from the total number of people to find out how many people don't have a skateboard.",
#  'How many of the four main individuals are wearing baseball caps?': '1. Are there four main individuals in the image?\n2. Are any of the individuals wearing baseball caps? \n3. How many individuals are wearing baseball caps?',
#  'How many racquets?': '1. Are there any racquets?\n2. How many racquets are there?',
#  'What is the woman wearing?': '1. Is there a woman in the image?\n2. What is the woman wearing?',
#  'What type of photo is this?': '1. Is there a photo?\n2. What are the characteristics of the photo?\n3. What are the visual elements in the photo?\n4. What is the subject of the photo?\n5. What is the composition of the photo?\n6. What is the lighting in the photo?\n7. What is the color scheme of the photo?\n8. What is the mood or atmosphere of the photo?\n9. What is the style or genre of the photo?\n10. What type of photo does this belong to?',
#  'Is this a shop?': '1. Is there a physical location depicted in the image?\n2. Is there a building or structure in the image?\n3. Does the building or structure display characteristics typically associated with a shop, such as a storefront or signage?\n4. Is there any indication or evidence of commercial activity taking place within the building or structure?\n5. Does the image include any objects or features commonly found in a shop, such as shelves, merchandise, or cash registers?\n6. Is there any text or visual cues suggesting that the establishment is a shop?\n7. Is there any additional information or context about the image that could confirm or refute the presence of a shop?',
#  'What sport is this?': '1. Is there a sport being played in the given image?\n2. What are the characteristics of the sport being played in the image?\n3. What equipment or props are being used in the sport being played?\n4. Are there any specific rules or regulations associated with the sport being played?\n5. Can we identify any specific gestures or movements that are unique to the sport being played?\n6. What is the name of the sport being played in the image?',
#  'What are the people holding?': '1. Are there people in the image?\n2. Are the people holding something?\n3. What are the people holding?',
#  'How many legs are in the image?': '1. Is there an image?\n2. Are there objects in the image?\n3. Are there living creatures in the image?\n4. Are there animals in the image?\n5. Do the animals have legs?\n6. How many legs are in the image?',
#  'What is the group of people holding in their hand?': 'Expected output: \n1. Are there people in the image?\n2. Is there a group of people in the image?\n3. Are they holding something in their hand?\n4. What are the people holding in their hand?',
#  'Are they happy?': '1. Who are "they" referring to?\n2. What is the current situation of "they"?\n3. Are there any visible signs of happiness in "them"?\n4. Are there any verbal or non-verbal indications of happiness from "them"?\n5. Are there any external factors that could affect their happiness?\n6. Is there any context or background information that could provide insight into their happiness?',
#  'Is the game live or on television?': '1. Is there a game being played?\n2. Is the game being broadcasted?\n3. Is the game being broadcasted on television?\n4. Is the game being broadcasted live?',
#  'Are the trying to fix the train?': '1. Is there a train?\n2. Is the train broken?\n3. Are there people near the train?\n4. Are the people trying to fix something?\n5. Are the people trying to fix the train?',
#  'What color is the locomotive?': '1. Is there a locomotive in the given image?\n2. What is the color of the locomotive?',
#  'Is the train black?': '1. Is there a train?\n2. What is the color of the train?',
#  'Is this an evening scene?': '1. What is this scene?\n2. What are the visual elements in this scene?\n3. Is there a depiction of the sky?\n4. Does the sky show signs of sunset or darkness?\n5. Are there any specific indications of time, such as streetlights or moon?\n6. Does the overall lighting suggest it is evening?',
#  'Is this a desert scene?': '1. What is depicted in the scene?\n2. Does the scene contain sand or barren land?\n3. Are there any cacti or desert plants present?\n4. Is the weather hot and dry?\n5. Are there any signs of oasis or water bodies?\n6. Are there any camels or desert animals visible?\n7. Are there any sand dunes or desert-specific geographical features present?\n8. Does the scene resemble typical desert landscapes?\n9. Is there any indication of a desert environment?\n10. Is the overall atmosphere or ambiance of the scene consistent with a desert setting?',
#  'How many passengers does this bus carry?': '1. Is there a bus in the image?\n2. Are there any passengers visible on the bus?\n3. If yes, how many passengers are visible on the bus?',
#  'Is this a city street?': '1. Is there a street in the image?\n2. Is it an urban environment?\n3. Are there buildings and infrastructure present?\n4. Is there any traffic or vehicles on the street?\n5. Are there any pedestrians or people on the street?\n6. Does the street have sidewalks or pavements?\n7. Does the street have streetlights or lampposts?\n8. Is there any signage or road markings on the street?\n9. Is there any public transportation present on the street?\n10. Is there any evidence of commercial or residential activity on the street?\n11. Can we identify any specific landmarks or features commonly found in a city street environment?\n12. Based on the overall visual cues and characteristics, does the image resemble a typical city street?',
#  'How would you call for more information about the bus?': '1. Is there a bus?\n2. Is there a need for more information about the bus?\n3. How would one go about calling for more information about the bus?',
#  'Which direction is the turn lane going?': '1. Is there a turn lane?\n2. Which direction is the turn lane going?',
#  'Is she wearing a bonnet?': '1. Is there a person in the image?\n2. Is the person female?\n3. Is the person wearing a head covering?\n4. Is the head covering a bonnet?',
#  "Was the woman's collar treated with starch?": '1. Is there a woman in the image?\n2. Is the woman wearing a collar?\n3. Was the collar treated with starch?',
#  'What pattern does the woman have on?': '1. Is there a woman in the given image?\n2. Is the woman wearing any pattern?\n3. What is the pattern that the woman is wearing?',
#  'Where is this?': '1. What is being referred to by "this" in the question?\n2. Is there an image or a specific context provided?\n3. Is there any additional information given that can help identify the location?\n4. Are there any landmarks or recognizable features in the image/context?\n5. Can any clues be gathered from the surrounding objects or people in the image/context?',
#  'Is it going to storm?': '1. Are there any signs of dark clouds or thunderstorms in the sky?\n2. Is there any lightning or thunder?\n3. Is there any strong wind or gusts?\n4. Is there any heavy rain or precipitation?\n5. Are there any weather warnings or alerts issued?\n6. Are there any changes in atmospheric pressure?\n7. Are there any changes in humidity levels?\n8. Are there any changes in temperature?\n9. Are there any indications of a storm approaching?',
#  'What kind of animal is on the beach?': "1. Is there an animal on the beach?\n2. What does the animal look like?\n3. What are the characteristics of the animal?\n4. What kind of animal does it resemble?\n5. Can we identify the animal's species?",
#  'What is running across the beach?': '1. Is there a beach?\n2. Is there something running across the beach?',
#  'How many open umbrellas are there on the beach?': '1. Is there a beach in the image?\n2. Are there any umbrellas in the image?\n3. Are the umbrellas open?\n4. How many open umbrellas are there on the beach?',
#  'How many umbrellas do you see?': '1. Do you see any objects in the given image?\n2. Are there any umbrellas among the objects that you see?\n3. How many umbrellas do you see?',
#  'What is causing the smoke?': '1. Is there smoke?\n2. What is the source of the smoke?',
#  'How many striped objects are in the photo?': '1. Is there a photo?\n2. Are there any objects in the photo?\n3. Are there any striped objects in the photo?\n4. How many striped objects are in the photo?',
#  'What ethnicity is the man?': "1. Is there a man in the image?\n2. What are the physical features of the man?\n3. Is there any indication of the man's cultural background or heritage?\n4. Can the man's ethnicity be determined based on his appearance or any contextual clues?",
#  'What color is the carpet in the middle of the floor?': '1. Is there a carpet in the middle of the floor? \n2. What is the color of the carpet?',
#  'Does this room have a low ceiling?': '1. Is there a room in the image?\n2. Does the room have a ceiling?\n3. Is the height of the ceiling considered low?',
#  'What color hat is this man wearing?': '1. Is there a man in the image?\n2. Is the man wearing a hat?\n3. What color is the hat?',
#  'What color are the shoelaces?': 'Expected output:\n1. Are there any shoelaces?\n2. What are the objects that have shoelaces?\n3. What is the color of the objects with shoelaces?',
#  'Is the man wearing shorts or pants?': '1. Is there a man in the given image?\n2. What is the man wearing on his lower body?\n3. Are the lower body garments shorts?\n4. Are the lower body garments pants?',
#  'Is a person wearing a hooded sweatshirt?': '1. Is there a person in the image?\n2. Is the person wearing a sweatshirt?\n3. Is the sweatshirt a hooded sweatshirt?',
#  'Is he wearing a helmet?': '1. Is there a person in the image?\n2. Is he visible in the image?\n3. Is he wearing any headgear?\n4. Is the headgear a helmet?',
#  "Which way is the man's hat facing?": '1. Is there a man in the image?\n2. Is the man wearing a hat?\n3. Which direction is the hat facing?',
#  "What color is the guy's shirt?": "1. Is there a guy in the image?\n2. Is he wearing a shirt?\n3. What color is the guy's shirt?"}

# %%
# !pwd
# Out:
# /root/autodl-tmp/Otter/Otter/src/otter_ai

# %% [markdown]
# ### BLIP2 baseline

# %%
with open('/root/autodl-tmp/Decomposing-Complex-Visual-Textual-Tasks-into-Intermediate-Questions-for-Multi-Modal-COT/vqav2_anwers.pkl', 'rb') as f2:
    all_answers = pickle.load(f2)

# %%
os.path.isabs('/root/autodl-tmp/Decomposing-Complex-Visual-Textual-Tasks-into-Intermediate-Questions-for-Multi-Modal-COT/')
# Out:
# True

# %%
all_answers1000 = all_answers[:1000]
all_answers1000
# Out:
# [['net', 'netting', 'mesh'],
#  ['pitcher', 'catcher'],
#  ['orange'],
#  ['yes', 'no'],
#  ['white'],
#  ['skiing'],
#  ['red', 'red and white', 'black'],
#  ['frisbee', 'white frisbee', 'frisbie', 'flying disc'],
#  ['yes'],
#  ['frisbee'],
#  ['yes'],
#  ['yes'],
#  ['airplane',
#   'plane trail',
#   'contrail',
#   'jet trail',
#   'snow',
#   'contrails',
#   'jet stream',
#   'air trail'],
#  ['yes', 'no'],
#  ['white and purple',
#   'white',
#   'purple and white',
#   'white and lavender',
#   'lavender and white'],
#  ['brushing teeth', 'brushing', 'brushing their teeth', 'toothbrush'],
#  ['yes'],
#  ['no'],
#  ['waiting', 'standing', 'walking', 'unknown', 'frowning', 'pouting'],
#  ['yes', 'no', 'poorly'],
#  ['no', 'yes'],
#  ['no'],
#  ['no', 'yes'],
#  ['yes', 'no'],
#  ['black white', 'black and white', 'white and gray', 'black white gray'],
#  ['no', 'yes'],
#  ['no'],
#  ['yes'],
#  ['skateboard'],
#  ['1', '3', '2'],
#  ['backwards', 'blue'],
#  ['no'],
#  ['green', 'green and black'],
#  ['yes'],
#  ['motorbike', 'motorcycle', 'dirt bike', 'motocross bike'],
#  ['pillow sham',
#   'frills',
#   'pillow case',
#   'pillowcases',
#   'nothing',
#   'gray',
#   'note',
#   'cover',
#   'paper',
#   'sign'],
#  ['2'],
#  ['no', 'yes'],
#  ['no', 'yes'],
#  ['purse', 'handbag'],
#  ['yes', 'no', 'no windows'],
#  ['skiing', 'snow ski'],
#  ['1'],
#  ['no'],
#  ['skiing'],
#  ['blue and white', 'gray'],
#  ['ski clothes',
#   'clothes',
#   'skis',
#   'snowsuit',
#   'ski pants and jacket',
#   'helmet',
#   'blue jacket and black pants'],
#  ['no'],
#  ['blue', 'blue and white'],
#  ['yes'],
#  ['poles', 'ski poles', 'skis', 'ski pole', 'pole'],
#  ['no', 'yes'],
#  ['surfboard', 'surfing'],
#  ['yes'],
#  ['yes'],
#  ['yes'],
#  ['dog on surfboard',
#   'dog and surfboard',
#   'surfboard',
#   'surfboard and dog',
#   'dog'],
#  ["it's turned on",
#   'background',
#   'on',
#   'powered on',
#   'it is on',
#   "it's color of screen",
#   'off',
#   'power'],
#  ['no', 'yes'],
#  ['office', 'bedroom', 'conference room', 'living room', 'big', 'family room'],
#  ['50 inch',
#   '40 inch',
#   '20 feet',
#   'large',
#   '36',
#   '100 inches',
#   '75 inch',
#   "it's projector",
#   '60 inches'],
#  ['no'],
#  ['yes', 'no'],
#  ['big', 'very', 'very big', '46 inches', 'gigantic', '20 in', 'large'],
#  ['laptop', 'computer', 'remote'],
#  ['laptop', 'projector'],
#  ['vent', 'ceiling', 'air duct', 'tiles'],
#  ['document',
#   'outlook',
#   'word document',
#   'overhead presentation',
#   'website',
#   'web page',
#   'na',
#   'laptop screen'],
#  ['yes', 'no'],
#  ['yes', 'screen projection', 'monitor', 'screen projector'],
#  ['ms word',
#   'outlook',
#   'document',
#   'mirrored computer',
#   'computer',
#   'outlook web app',
#   'desktop screen',
#   'desktop'],
#  ['outlook web app',
#   'flight markup',
#   'outlook',
#   'design',
#   "can't see",
#   'business',
#   'extend with app',
#   "can't tell"],
#  ['black'],
#  ['yes'],
#  ['bear'],
#  ['yes'],
#  ['no', '0'],
#  ['3', '0'],
#  ['yes'],
#  ['wii', 'x box', 'game'],
#  ['yes'],
#  ['glasses', 'smile', 'sweat', 'eyeglasses'],
#  ['tree', 'trees'],
#  ['height',
#   'long neck',
#   'spots',
#   'they are tall',
#   'eating',
#   "they're animals",
#   'tall'],
#  ['yes'],
#  ['yes'],
#  ['by tree', 'africa', 'near tree', 'zoo', 'beside tree', 'yes', 'outside'],
#  ['no'],
#  ['tree', 'fallen tree', 'log', 'trees'],
#  ['yes', 'no'],
#  ['yes', 'no', '2'],
#  ['yes', 'no'],
#  ['log', 'dead tree', 'tree', 'trees', 'tree trunk'],
#  ['yes', 'no'],
#  ['yes', '1'],
#  ['no'],
#  ['no', 'yes'],
#  ['2', '1'],
#  ['no'],
#  ['2', 'giraffe'],
#  ['homeless', 'begging', 'he is homeless', 'resting', 'sitting'],
#  ['cross legged', 'indian style', 'legs folded'],
#  ['automatic', 'automatique', 'atm', 'automation', 'automate'],
#  ['5', '7', '6', '9'],
#  ['green'],
#  ['raft', 'platoon', 'boat', 'rubber raft boat'],
#  ['backpacks',
#   'bottom left',
#   'left corner',
#   'in left hand corner of photo',
#   'left',
#   'yes',
#   'behind chair',
#   'behind boxes',
#   'by boxes'],
#  ['family room',
#   'living room',
#   'den',
#   'playroom',
#   'main room',
#   'storage room'],
#  ['yes'],
#  ['pink', 'pink and white', 'pink and lavender and white', 'red'],
#  ['no', 'yes'],
#  ['right'],
#  ['yes'],
#  ['railing',
#   'fence',
#   'ledge',
#   'wall border',
#   'porch ledge',
#   'patio ledge',
#   'wall'],
#  ['right', 'not possible', 'left', 'no'],
#  ['no', 'yes', 'some'],
#  ['white'],
#  ['no', 'yes'],
#  ['yes', 'no'],
#  ['yes', 'no', 'maybe'],
#  ['no', 'yes'],
#  ['grass', 'yes'],
#  ['yes', 'no'],
#  ['fencing', 'mesh', 'leaves', 'wire fence', 'fence', 'wire mesh', 'wire'],
#  ['no'],
#  ['grass'],
#  ['2 years', 'young', 'adult', '3 years old', '10 years', '2', '20'],
#  ['yes', 'no'],
#  ['yes'],
#  ['knife', 'nothing'],
#  ['birthday cake', 'cake', 'yes'],
#  ['banana', "banana's", 'caramel', 'bananas'],
#  ['yes'],
#  ['chef', 'pastry chef'],
#  ['vanilla', 'fruit salad', 'banana'],
#  ['4'],
#  ['outdoor'],
#  ['yes', 'no'],
#  ['yes'],
#  ['white'],
#  ['no'],
#  ['no', 'yes'],
#  ['yes', 'no'],
#  ['nothing', 'mustard', 'toppings', 'condiments', 'sauce'],
#  ['bun', 'napkin', 'buns', 'pita bread'],
#  ['no'],
#  ['clouds', 'cloud'],
#  ['on dock',
#   'dock',
#   'pier',
#   'no trucks shown',
#   'outside',
#   'forklifts',
#   'by water'],
#  ['brown', 'brown and tan', 'red', 'tan', 'brown and white', 'no carpet'],
#  ['yes', 'no'],
#  ['silver', 'stainless steel'],
#  ['refrigerator', 'fridge', 'ref', 'light switch'],
#  ['no', 'yes'],
#  ['red',
#   'red and silver',
#   'red white and black',
#   'orange and silver',
#   'red and white'],
#  ['squares', 'rectangle', 'square', 'rectangles', 'round', 'r square'],
#  ['no', 'yes'],
#  ['no', 'yes'],
#  ['2', '5'],
#  ['no', 'yes'],
#  ['yes', 'no'],
#  ['yes', 'wmatacom'],
#  ['teddy bear', 'teddy'],
#  ['yes'],
#  ['black', 'brown one'],
#  ['no', 'yes'],
#  ['3', '4', '5', '1'],
#  ['elm', 'maple', 'not sure', 'birch', 'trunk', 'big one', 'unknown', 'oak'],
#  ['no'],
#  ['stripes', 'stripped', 'pinstripes'],
#  ['baseball'],
#  ['catcher', 'umpire', 'hitting ball'],
#  ['blue', 'light blue'],
#  ['beer', 'water'],
#  ['pail',
#   'pau',
#   "can't see",
#   'unclear',
#   "can't tell",
#   'coors',
#   'budweiser',
#   'ipa',
#   'sierra nevada',
#   'heineken'],
#  ['crosses athol ave',
#   'new york',
#   'corner of athol ave',
#   'bottom',
#   "can't tell",
#   '700 block',
#   'not sure',
#   '700',
#   'crossing athol ave'],
#  ['left and right',
#   'left or right',
#   'north',
#   'left',
#   'across',
#   'right',
#   'left to right'],
#  ['no', 'yes'],
#  ['nike', 'nike swoosh', 'livestrong'],
#  ['no'],
#  ['no', 'yes'],
#  ['yellow', 'yellow and white', 'yellow white', 'white yellow'],
#  ['yellow white',
#   'white yellow peach',
#   'orange white and yellow',
#   'yellow and white',
#   'yellow white and orange',
#   'white and yellow'],
#  ['3', '6', '2'],
#  ['no', 'yes'],
#  ['on cliff',
#   'precipice',
#   'mountain',
#   'on ledge',
#   'cliff',
#   'in middle',
#   'sitting on rock',
#   'on rock',
#   'crow'],
#  ['no', 'yes'],
#  ['right', 'sideways', 'east'],
#  ['no'],
#  ['midday', 'noon', 'morning', 'afternoon', 'mid day'],
#  ['2', '1', '3'],
#  ['3'],
#  ['2'],
#  ['elephant'],
#  ['gray'],
#  ['red and white', 'orange', 'red'],
#  ['small',
#   'smaller propeller plane',
#   'propeller',
#   'private',
#   "don't know",
#   'single propeller plane',
#   'small personal plane',
#   'biplane'],
#  ['yes'],
#  ['brown', 'gray brown', 'beige', 'tan', 'juniper green', 'gray'],
#  ['yes'],
#  ['on wall', 'wall', 'right upper corner', 'left side', 'right of window'],
#  ['yes', 'no'],
#  ['rolex', 'factory', 'man', 'people'],
#  ['no', 'yes', 'roman numerals'],
#  ['yes'],
#  ['clock',
#   'street and its surroundings',
#   'clock trees car building street signs',
#   'clock tree'],
#  ['6:10', '2:30', '6:30', '6 :10', '8:30'],
#  ['table', 'desk', 'sideboard'],
#  ['3'],
#  ['0', '1'],
#  ['blue', 'green'],
#  ['wood', 'woo'],
#  ['christmas', 'christmas trees', 'wooden', 'pine'],
#  ['no'],
#  ['spinach', 'broccoli', 'kale'],
#  ['yes'],
#  ['thick', 'thin', 'thick crust'],
#  ['yes', 'no'],
#  ['yes'],
#  ['no'],
#  ['cushion', 'pouch', 'bag', 'lunch pack'],
#  ['yes'],
#  ['yes'],
#  ['from', 'away from', 'away'],
#  ['2', '3'],
#  ['2', 'leaves', 'grass', 'tree branches'],
#  ['yes'],
#  ['yes', 'no'],
#  ['no'],
#  ['yes', 'no'],
#  ['necklace', 'nothing', 'neck chain'],
#  ['no', 'yes'],
#  ['8', '6', '7'],
#  ['countertop',
#   'bathroom',
#   'left',
#   'counter',
#   'on counter',
#   'on left side',
#   'left wall'],
#  ['shower', 'in shower', 'on vanity'],
#  ['yellow', 'white', 'clear', 'blocks', 'silver'],
#  ['rug', 'towel', 'bath mat'],
#  ['vinyl', 'plain', 'solid', 'solid color', 'stripes'],
#  ['brown', 'tan', 'orange'],
#  ['mirrors', 'no', 'yes'],
#  ['3', '2', '0'],
#  ['no'],
#  ['yes'],
#  ['1', '2'],
#  ['chair umpire', 'referee', 'umpire'],
#  ['wimbledon', 'wilson', 'w wilson'],
#  ['1', '2'],
#  ['yes', 'no'],
#  ['yes', 'no'],
#  ['12:40', '8:00', '8', '8 o clock'],
#  ['no', 'yes', '3'],
#  ['no', 'yes'],
#  ['no', 'yes', 'already flying'],
#  ['e'],
#  ['yes'],
#  ['no', 'yes'],
#  ['94', '24'],
#  ['hat', 'helmet', 'cap'],
#  ['yes', 'no'],
#  ['grazing', '50', 'eating'],
#  ['sheep', 'cows', 'goat', 'unknown', 'cow'],
#  ['10', '5', '0', '4', '19', 'around 6', '12', '3'],
#  ['count sheep',
#   'patty cake',
#   'none',
#   'frisbee',
#   'tag',
#   'counting sheep',
#   'running',
#   'rolling down hill',
#   'king of hill'],
#  ['hilltop',
#   'on top of hill',
#   'on hill',
#   'hill',
#   'far back',
#   'top of hill',
#   'standing on horizon'],
#  ['yes'],
#  ['no'],
#  ['white', 'white and brown', 'brown and white'],
#  ['yes', 'no'],
#  ['spanish',
#   'russian',
#   'german',
#   'arab',
#   'hebrew',
#   'iranian',
#   'african',
#   'english'],
#  ['melted', 'yes', 'creamy', 'grilled'],
#  ['no'],
#  ['1', 'hot dogs'],
#  ['yes'],
#  ['hot dog', 'carrot fries and dog', 'hot dog bacon', 'hot dog and fries'],
#  ['plate',
#   'making hot dogs',
#   'sausage',
#   'food',
#   'tile',
#   'cut food',
#   'platter',
#   'hold food',
#   'holding food',
#   'meat'],
#  ['lunch', 'dinner', 'american'],
#  ['no'],
#  ['mayonnaise', 'butter', 'butter sauce', 'horseradish', 'aioli', 'not sure'],
#  ['sausage', 'pork', 'hot dog', 'hot dog and sweet potato fries'],
#  ['onion', 'peppers', 'peppers and onion', 'seasoning', 'onions', 'hot'],
#  ['peppers and onions',
#   'onions',
#   'sauerkraut',
#   'peppers and onion',
#   'bacon',
#   'onion',
#   'grilled onions'],
#  ['butter', 'mayo', 'mayonnaise', 'mustard', 'sauce'],
#  ['hot dog onions and potatoes',
#   'butter',
#   'hot dog and sweet potato fries',
#   'hot dogs and french fries',
#   'hot dog bun mayonnaise peppers',
#   'hot dog roll onions fries',
#   'hot dog bun fries mayo',
#   'hot dog and fries',
#   'bun hot dog topping'],
#  ['onions', 'onions and peppers', 'grilled onions', 'peppers', 'bacon'],
#  ['no'],
#  ['no', 'yes'],
#  ['not very', 'not', 'very delicious', 'very', 'good', 'not at all'],
#  ['no vegetables',
#   'none',
#   'sweet potatoes onion',
#   'potatoes',
#   'no veg in bowl',
#   'mayo'],
#  ['1'],
#  ['fries', 'hot dog', 'mayonnaise', 'mayo', 'mustard', 'potato', 'butter'],
#  ['white'],
#  ['0', 'no pickle in sight', '5'],
#  ['butter', 'mayonnaise', 'dip', 'cheese'],
#  ['1'],
#  ['no', 'yes'],
#  ['bun', 'plate', 'white tray'],
#  ['1'],
#  ['sweet potatoes', 'carrots', 'sweet potato fries', 'fries', 'hot dogs'],
#  ['cut long ways', 'long ways', 'cut long', 'long', 'cut'],
#  ['yes', 'no'],
#  ['no', 'yes'],
#  ['mayo', 'mayonnaise', 'sauce', 'butter'],
#  ['sweet potato', 'rutabaga', 'sweet potatoes', 'carrot', 'potato'],
#  ['hot dogs',
#   'bacon',
#   'hot dog',
#   'sausage dog',
#   'no',
#   'polish sausage',
#   'sausage'],
#  ['sausage', 'polish', 'hot dog', 'pork'],
#  ['onions',
#   'hot dog and onions',
#   'hot dog',
#   'sausage',
#   'relish',
#   'bacon',
#   'peppers'],
#  ['yes', 'no', 'no fries'],
#  ['yes', 'no'],
#  ['no'],
#  ['hot dog', 'pig', 'cow', 'no', 'beef'],
#  ['no'],
#  ['yes', 'no'],
#  ['no'],
#  ['yes'],
#  ['yes'],
#  ['peppers', 'onions', 'onions relish', 'red peppers', 'chili'],
#  ['peppers chives',
#   'none',
#   'carrots onions',
#   'not possible',
#   'peppers',
#   'no pizza',
#   'peppers and onions',
#   'not pizza',
#   'potatoes'],
#  ['no'],
#  ['yes', 'no'],
#  ['parsley', 'butter', 'mayonnaise', 'basil', 'mayo'],
#  ['1', '2', '3'],
#  ['mayo', 'horseradish', 'mayonnaise', 'butter', 'honey mustard'],
#  ['none', 'sweet', 'sweet potato', 'red', 'well cooked'],
#  ['hot dog',
#   'sausage and brisket sandwich',
#   'bacon',
#   'sausage sandwich and fries',
#   'hot dog and fries',
#   'sausage and potatoes',
#   'food'],
#  ['no'],
#  ['flowers', 'dead kind', 'daisies'],
#  ['floral', 'flowers', 'flowered'],
#  ['left', 'right'],
#  ['no'],
#  ['yes'],
#  ['2'],
#  ['no', 'yes'],
#  ['green', 'yellow', 'white', 'white and yellow', 'yellow and white'],
#  ['no'],
#  ['white', 'yellow', 'green', 'greenish yellow'],
#  ['yellow', 'yellow and white', 'orange'],
#  ['no towel rack', 'no', 'yes'],
#  ['yes', 'no'],
#  ['yellow', 'yellow green', 'green'],
#  ['camera flash',
#   'outside',
#   'lamp',
#   'hallway',
#   'window',
#   'outside bathroom',
#   'outside room'],
#  ['yes'],
#  ['9', '2', '7', '8', '1', '3', '10', '16'],
#  ['yes'],
#  ['1', '3'],
#  ['peace',
#   'pizza',
#   'no name restaurant and cafe',
#   'no',
#   'church',
#   'unclear',
#   'nothing'],
#  ['peace way', 'peace way hotel'],
#  ['2'],
#  ['car', 'car truck', 'automobile', 'driving', 'cars'],
#  ['yes', 'no'],
#  ['no', 'yes'],
#  ['inverted air cargo',
#   'everts air cargo',
#   'not possible',
#   'air cargo',
#   'nerts air cargo',
#   'converts air cargo'],
#  ['', 'r', 'v', 'n'],
#  ['commercial', 'cargo plane', 'cargo', 'carrier', 'air cargo', 'propeller'],
#  ['dutchsimba', 'dutch simba'],
#  ['everts air cargo',
#   'everts air',
#   'erts air cargo',
#   'converts air cargo',
#   'air cargo'],
#  ['everts air cargo',
#   'not visible',
#   'air cargo',
#   'nerts air cargo',
#   "can't say"],
#  ['plane',
#   'everts air cargo',
#   'cargo plane',
#   'cargo',
#   'air cargo',
#   'prop plane',
#   'airplane'],
#  ['movable flight of stairs', 'stairs', 'ladder'],
#  ['yes'],
#  ['against wall',
#   'middle',
#   'left side',
#   'in room',
#   'wall',
#   'stand',
#   'next to wall',
#   'near wall',
#   'table'],
#  ['no'],
#  ['no'],
#  ['2', '3'],
#  ['tower', 'unsure', 'abstract', 'moodle', 'multiple pictures', 'art'],
#  ['rug', 'circles', 'spots', 'area rug'],
#  ['3', '2'],
#  ['no', 'yes'],
#  ['floor', 'floor lamp', 'tall', 'table lamp'],
#  ['no', 'yes'],
#  ['4'],
#  ['floor lamp',
#   'tall standing lamp in corner',
#   'corner one',
#   'one in far corner',
#   'floor',
#   'back',
#   'one in corner',
#   'in corner',
#   'back one'],
#  ['1'],
#  ['gray', 'tan', 'light brown'],
#  ['3', '4'],
#  ['1', '2'],
#  ['baseball', 'baseball cap', 'ball cap', 'baseball hat'],
#  ['black', 'blue'],
#  ['texting',
#   'sitting',
#   'looking at phones',
#   'playing on their cell phones',
#   'playing on phones',
#   'on their phones',
#   'phone'],
#  ['above street',
#   'overhead',
#   'above stop light',
#   'pole',
#   'streetlight',
#   'somerset',
#   'on stop light',
#   'over street'],
#  ['crosswalk', 'street', 'sidewalk', 'in crosswalk', 'across street'],
#  ['yes'],
#  ['somerset', 'nothing'],
#  ['yes', 'no'],
#  ['urban', 'suburban'],
#  ['in street', 'sidewalk', 'on street', 'crosswalk', 'street'],
#  ['2'],
#  ['public bus is on left', 'bus'],
#  ['yes'],
#  ['green'],
#  ['light', 'traffic light', 'sign'],
#  ['afternoon', 'noon', 'day', 'mid day', 'evening', 'morning'],
#  ['yes'],
#  ['1'],
#  ['4', '5'],
#  ['1'],
#  ['yes'],
#  ['guatemala', 'cugremals'],
#  ['no', 'yes'],
#  ['3', '1'],
#  ['skis', 'snow', 'mountain', 'snowboard'],
#  ['2'],
#  ['skiing'],
#  ['yes', 'no'],
#  ['1', '2'],
#  ['4', '5', '3'],
#  ['no', 'yes'],
#  ['bike', 'bridge', 'road', 'boat', 'boardwalk'],
#  ['yes'],
#  ['gray', 'brown', 'blue', 'beige', 'bray'],
#  ['yes'],
#  ['cheese'],
#  ['window',
#   'paper',
#   'origami',
#   'leaves',
#   'paper cranes',
#   'what flowers are these',
#   'papers'],
#  ['no', 'yes'],
#  ['real'],
#  ['sunflower',
#   'color',
#   "i don't know",
#   'no idea',
#   's',
#   'unsure',
#   'sun',
#   'elizabeth',
#   'none'],
#  ['3', '2'],
#  ['blue'],
#  ['birthday', 'anniversary', 'retirement'],
#  ['flower',
#   "can't tell",
#   'words',
#   'anniversary',
#   'wedding',
#   'married',
#   'scrollwork',
#   'lettering',
#   'none'],
#  ['inside', 'in'],
#  ['yes'],
#  ['no'],
#  ['m', 'hb', 'icing', 'jk', 'not sure', 'mk', 'md', 't', 'js'],
#  ['direction of sunlight',
#   'low light',
#   'shadows',
#   'sun',
#   'lighting',
#   'position of sun',
#   'bad light',
#   'sunset',
#   'glare',
#   'backlighting'],
#  ['6', '7'],
#  ['yes', 'no'],
#  ['knife'],
#  ['tomatoes', 'tomato', 'watermelon', 'cherry'],
#  ['yes'],
#  ['yes', 'no'],
#  ['no'],
#  ['yes'],
#  ['red', 'red brown white gray'],
#  ['no', 'yes'],
#  ['oak', 'pine', 'bush', 'shrub', 'evergreen', 'green', 'unknown'],
#  ['no'],
#  ['yes'],
#  ['wood', 'roof', 'siding', 'cement', 'white', 'brick', 'concrete'],
#  ['red', 'white', 'white and pink', 'white and red', 'pink'],
#  ['1'],
#  ['30 ft',
#   '20 feet',
#   '100 feet',
#   '3 stories',
#   'very',
#   'regular',
#   'really tall',
#   '30 feet',
#   'medium high',
#   '2 stories'],
#  ['bricks', 'shingles', 'tile', 'clay'],
#  ['1'],
#  ['yes', 'no'],
#  ['no', 'yes', "don't know"],
#  ['nothing', 'clock', 'flag', 'bell', 'steeple', 'vane', 'weathervane'],
#  ['no'],
#  ['white', 'white and black'],
#  ['trees', 'windows', 'windows and vines', 'vines'],
#  ['bushes', 'building', 'leaves', 'grass', 'house'],
#  ['yes', 'no'],
#  ['0'],
#  ['yes', 'no'],
#  ['no', 'yes'],
#  ['no', 'yes'],
#  ['yes', 'no'],
#  ['no'],
#  ['5', '4', '6', '7'],
#  ['6', '4', '5'],
#  ['no', 'yes'],
#  ['petting sheep', 'petting', 'kissing sheep'],
#  ['hay'],
#  ['straw', 'hay', 'grain', 'love', 'nothing', 'pellets'],
#  ['2'],
#  ['no', 'yes'],
#  ['no', 'yes', 'in front of plates'],
#  ['white'],
#  ['knife and spoon', 'knife', 'spoon and butter knife', 'spoon knife'],
#  ['yellow and black', 'yellow'],
#  ['yes'],
#  ['phone', 'ski pole', 'ski poles', 'skii', 'pole'],
#  ['black', 'cannot tell'],
#  ['patterned', 'solid', 'yes', 'pattern'],
#  ['1'],
#  ['no'],
#  ['black and gray', 'black'],
#  ['1'],
#  ['black'],
#  ['yes'],
#  ['yes'],
#  ['yes'],
#  ['walking'],
#  ['ice', 'foam', 'water', 'fog', 'nothing', 'fish'],
#  ['no'],
#  ['3', '2'],
#  ['yes', 'no', '3'],
#  ['no'],
#  ['yes'],
#  ['yes', 'no'],
#  ['she just did laundry',
#   'laundry',
#   'lack of storage',
#   "it's hot",
#   "she's messy",
#   "haven't put away yet",
#   'messy',
#   "bed isn't made",
#   'yes'],
#  ['yes'],
#  ['red', 'pink', 'orange'],
#  ['pepsi'],
#  ['yes'],
#  ['del taco', 'panda express'],
#  ['great', 'good', 'hundreds', 'high', 'fair', 'decent'],
#  ['5', '6', '4', 'several'],
#  ['panda',
#   'marquee',
#   'building',
#   'panda express',
#   'scoreboard',
#   'panda express logo',
#   'billboard'],
#  ['gray', 'white'],
#  ['2'],
#  ['1:50', 'older', '1:51', '1:55', '2:50'],
#  ['no', 'yes'],
#  ['purple', 'pink', 'purple and pink'],
#  ['yes'],
#  ['florist', 'flower shop'],
#  ['no', 'yes'],
#  ['yes', 'no'],
#  ['no', 'yes'],
#  ['yes', 'no'],
#  ['gray', 'white'],
#  ['7', '14', '13', '10', '8', '9', '12'],
#  ['africa'],
#  ['no', 'zebras', 'on right', 'zebra'],
#  ['no'],
#  ['yes', 'no'],
#  ['banana', 'bananas'],
#  ['no', 'yes'],
#  ['blue white', 'blue and white', 'blue'],
#  ['no'],
#  ['yes'],
#  ['yes'],
#  ['teddy bears', 'stuffed animals', 'bears', 'dolls'],
#  ['socks', 'tennis shoes', 'sneakers', 'shoes'],
#  ['drinking', 'drinking water', 'grazing', 'eating', 'watching'],
#  ['yes', 'no'],
#  ['giraffe', 'giraffes'],
#  ['yes'],
#  ['yes'],
#  ['yes', 'no'],
#  ['yes'],
#  ['no', 'yes'],
#  ['red', 'brown', 'red brick'],
#  ['yes'],
#  ['no', '0 here', 'ones in back', 'no buses', '0', 'left'],
#  ['tennis', 'basketball', 'soccer'],
#  ['no'],
#  ['no', 'yes'],
#  ['no'],
#  ['yes'],
#  ['surfboard'],
#  ['red'],
#  ['red', 'brown', 'brown red'],
#  ['red'],
#  ['special'],
#  ['no', 'yes'],
#  ['blue and yellow',
#   'yellow blue',
#   'blue',
#   'blue yellow',
#   'it is yellow blue white',
#   'blue and yellow and white'],
#  ['no', 'unknown'],
#  ['blue and yellow',
#   'blue yellow white',
#   'blue yellow and white',
#   'yellow and blue',
#   'yellow blue and white',
#   'blue white and yellow'],
#  ['yes'],
#  ['yes', 'no'],
#  ['3', '1', '2'],
#  ['1'],
#  ['yes', 'no'],
#  ['1'],
#  ['right', 'different', 'east', 'west', 'north'],
#  ['yes'],
#  ['walking', 'standing still'],
#  ['no', 'no zebras', 'yes'],
#  ['3'],
#  ['no'],
#  ['zebras', 'zebra', 'no one', 'nobody'],
#  ['3'],
#  ['no', 'yes', 'maybe'],
#  ['yellow'],
#  ['yellow'],
#  ['1', '3', '2'],
#  ['5'],
#  ['no'],
#  ['no', 'maybe', 'yes'],
#  ['plate', 'on plate on table', 'on plate', 'saucer'],
#  ['cupcake'],
#  ['post it', 'post it notes', 'post its', 'sticky notes'],
#  ['peanut', 'cashew', 'walnuts', 'cashews', 'peanuts'],
#  ['broccoli'],
#  ['no', 'dish'],
#  ['white',
#   'blue',
#   'vanilla',
#   'cake',
#   'whipped',
#   'strawberry',
#   'sugar icing',
#   'white icing',
#   'sugar'],
#  ['no'],
#  ['yes'],
#  ['soldier', 'human', 'army', 'army man'],
#  ['vanilla', 'chocolate', 'white'],
#  ['cutting tie', 'cutting'],
#  ['yes'],
#  ['yes'],
#  ['3', '2'],
#  ['0', '1', '3', '2'],
#  ['yes', 'no'],
#  ['entry room', 'living room', 'sunroom', 'parlor', 'family room', 'living'],
#  ['no', 'yes'],
#  ['parking lot', 'water control', 'beach', 'road', 'lot', 'park'],
#  ['0', '2', '3', '6', '4'],
#  ['no'],
#  ['5', '4'],
#  ['black', 'dark brown', 'brown'],
#  ['no', 'yes'],
#  ['cows', 'cattle', 'yaks', 'cow'],
#  ['no', 'yes'],
#  ['herding', 'herding cattle', 'squinting'],
#  ['yes'],
#  ['3'],
#  ['table', 'on coffee table', 'on table'],
#  ['fish'],
#  ['yes', 'maybe', 'no'],
#  ["there's not",
#   'in kitchen',
#   'nightstand',
#   'on table',
#   'counter',
#   'side table',
#   'vases',
#   'table'],
#  ['yes', 'no', 'possibly'],
#  ['yes'],
#  ['yes'],
#  ['50', 'lot', '56', 'no telling', 'many', 'more than 20', '60', '55'],
#  ['yes'],
#  ['overcast'],
#  ['yes'],
#  ['brown gray',
#   'red',
#   'gray',
#   'black',
#   'brown',
#   'roof shingles are grey',
#   'orange'],
#  ['cross'],
#  ['no'],
#  ['no'],
#  ['yes'],
#  ['yes'],
#  ['no'],
#  ['hold food',
#   'toaster oven',
#   'microwave',
#   'for even cooking',
#   'holding food',
#   'grill',
#   'oven',
#   'food',
#   'putting things on'],
#  ['yes', 'no'],
#  ['yes', 'no'],
#  ['wood', 'tile', 'cannot tell', 'concrete'],
#  ['no', 'yes', 'maybe', "can't tell"],
#  ['4', '1', '5', '3', '2'],
#  ['no', 'yes', 'not microwave'],
#  ['yes'],
#  ['pink', 'pink and yellow'],
#  ['12:56', '11:55', '12:55', '11:57', '11:00'],
#  ['house',
#   'wood',
#   'clock case',
#   'birdhouse',
#   'church',
#   'clock tower',
#   'steeple'],
#  ['1', '2'],
#  ['yes', 'es'],
#  ['no'],
#  ['yellow red',
#   'red and yellow',
#   'red yellow',
#   'yellow and red',
#   'beige red',
#   'white and red'],
#  ['892'],
#  ['bus',
#   'front of bus',
#   'no open door',
#   'nowhere',
#   'not open',
#   'middle of bus'],
#  ['no'],
#  ['2'],
#  ['yes'],
#  ['silver'],
#  ['hair dryer', 'puppy', 'blow dryer', 'hair blower', 'dog'],
#  ['tow truck', 'truck', 'semi', 'large truck'],
#  ['12',
#   '11',
#   '5',
#   '7',
#   '6',
#   'truck two bus three house seven',
#   '8',
#   "don't know"],
#  ['no', 'yes'],
#  ['yes'],
#  ['no'],
#  ['no', 'blue', "no it's not"],
#  ['white'],
#  ['person', 'human', 'people', 'he is', 'no one', 'adventurous eater'],
#  ['yes'],
#  ['round', 'rectangle', 'no pole', 'square', 'no pole is shown', 'bed'],
#  ['yes', 'wood'],
#  ['yes'],
#  ['2', '3'],
#  ['bunk bed', 'bunk beds', 'bunk'],
#  ['yes'],
#  ['no', 'yes'],
#  ['orange', 'copper', 'umber'],
#  ['hot dogs', 'wieners', 'sausages'],
#  ['by plates',
#   'on side bar',
#   'to side',
#   'left side of grill',
#   'besides grill',
#   'table',
#   'bags',
#   'yes',
#   'next to styrofoam plates'],
#  ['fundraiser',
#   'barbeque for friends or family',
#   'party',
#   'for festival',
#   'barbecue',
#   'to eat',
#   'cookout',
#   'for sale',
#   'to feed people'],
#  ['ancient', 'no'],
#  ['1:50', '6:00', '12:53', 'unsure', '12:55', '11:05', 'noon', '1:00'],
#  ['no', 'yes'],
#  ['yes'],
#  ['5', '5 snowboards', '6'],
#  ['loon mountain',
#   'hunter mountain',
#   'lookout',
#   'rockies',
#   'ski resort',
#   'snowy one',
#   'mt mckinley',
#   'rainier',
#   'vail',
#   'sweden'],
#  ['apron', 'apon'],
#  ['kitchen'],
#  ['cooking', 'dishes', 'opening steamer', 'opening oven'],
#  ['rose', 'ring', 'propose', 'engagement ring'],
#  ['black and white', 'black white', 'black', 'white'],
#  ['one way', 'someone got engaged'],
#  ['right', 'left', 'one way', 'opposite sign'],
#  ['light', 'street light', 'one way sign', 'traffic light', 'one way', 'none'],
#  ['no'],
#  ['yes'],
#  ['no'],
#  ['yes'],
#  ['no'],
#  ['yes'],
#  ['no'],
#  ['stop'],
#  ['yes', 'no just reflection', 'no'],
#  ['right', 'neither', 'left', 'both', 'no', 'one in stripes', 'none', 'yes'],
#  ['20', 'more than 50', '100', 'many', '200', '300', '89', 'lot'],
#  ['no'],
#  ['yes', "don't know", 'no'],
#  ['2', '3'],
#  ['no'],
#  ['no', 'yes'],
#  ['blue'],
#  ['female', 'girls', 'male', 'boys', 'girl'],
#  ['blue'],
#  ['no'],
#  ['brushing', 'brushing it', 'combing it', 'combing', 'adjusting hair clip'],
#  ['on table',
#   'behind man',
#   'background',
#   'end table',
#   'night stand',
#   'on left',
#   'top left'],
#  ['tie', 'necktie', 'yes'],
#  ['no'],
#  ['hot dog'],
#  ['brown', 'tan', 'beige'],
#  ['on table', 'table', 'on left', 'popcorn', 'left side', 'left'],
#  ['$1', "don't know", '1 dollar', '$2.50', '1', 'nothing', 'not shown'],
#  ['racket', 'tennis racket', 'racquet', 'ball', 'tennis ball tennis racket'],
#  ['6', '7', '5', '2'],
#  ['yes', 'no'],
#  ['yes'],
#  ['fork',
#   'fork or knife',
#   'butter knife and fork',
#   'knife and fork',
#   'fork and knife',
#   'fork knife',
#   'fork and knives'],
#  ['restaurant', 'wedding hall', 'fancy restaurants'],
#  ['silver'],
#  ['no', 'yes'],
#  ['no'],
#  ['2', '3', '16'],
#  ['no'],
#  ['restaurant', 'in dining area', 'inside', 'dining room'],
#  ['cat'],
#  ['bed', 'on bed'],
#  ['yes'],
#  ['blue', 'green', 'gray', 'black'],
#  ['yes'],
#  ['pink'],
#  ['block sun',
#   "it's sunny",
#   'sun',
#   "its' sunny",
#   'sun protection',
#   'keep sun off',
#   'protection from sun',
#   'sunscreen'],
#  ['3'],
#  ['3', ''],
#  ['yes', 'no'],
#  ['yes', 'no', 'water'],
#  ['sand', 'beach', 'sandy beach', 'board'],
#  ['no'],
#  ['white', 'black', 'swimsuit', 'tan'],
#  ['surfboard', 'wind boards', 'water', 'ocean', 'sea', 'kayak'],
#  ['cold', '90', '60', '55', '70', 'warm', 'cool', 'chilly'],
#  ['yes', 'maybe', "can't tell", 'no'],
#  ['no'],
#  ['sand', 'beach', 'beach sand'],
#  ['yes', 'no'],
#  ['surfboards', 'sand', 'surfboard', 'parasail', 'sailboat'],
#  ['parachutes', 'kites', 'parasail', 'kiteboarding kites'],
#  ['tennis shoes',
#   'there is no skateboarder',
#   'unknown',
#   'dc',
#   'billabong',
#   'none',
#   "cabela's",
#   'nike'],
#  ['yes'],
#  ['yes'],
#  ['no', 'yes'],
#  ['no'],
#  ['yes'],
#  ['no'],
#  ['man', 'star', 'no', '0', 'standing on shore', 'beach', '1', 'standing'],
#  ['one behind',
#   'no',
#   'furthest back',
#   'none',
#   'front',
#   'man in water',
#   'no kite',
#   'in background',
#   'first'],
#  ['yes'],
#  ['nimbus',
#   'rain clouds',
#   'cumulonimbus',
#   'clouds',
#   'white',
#   'cumulus',
#   'thin',
#   'dark'],
#  ['surfing',
#   'watching',
#   'standing',
#   'looking',
#   'standing on beach',
#   'looking at surf'],
#  ['male'],
#  ['star'],
#  ['black', 'black blue red', 'hawaiian style'],
#  ['white', 'red and white', 'white and red', 'white red'],
#  ['1', '4'],
#  ['black blue red yellow',
#   'black blue red orange yellow',
#   'red blue yellow purple',
#   'red blue black yellow',
#   'black red blue yellow',
#   'blackblue red yellow',
#   'blue red yellow black'],
#  ['no', 'yes'],
#  ['red', 'orange'],
#  ['yes'],
#  ['tracks', 'trees', 'railroad', 'rails'],
#  ['light', 'night light', 'candle', 'lamp'],
#  ['banana', 'pear', 'bananas'],
#  ['rotten',
#   "they don't like oranges",
#   'personal preference',
#   "they just don't",
#   'wax',
#   'too acidic',
#   'acidic',
#   'have to peel',
#   'allergic to it',
#   'to citrusy'],
#  ['orange', 'red'],
#  ['yes', 'no'],
#  ['1', '0', '3', '2'],
#  ['middle', 'car', 'middle vehicle', 'subaru', 'one in middle', 'middle one'],
#  ['yes'],
#  ['4', '3 sets', '6', '3'],
#  ['thin crust', 'cheese', 'thin', 'veggie', 'broccoli'],
#  ['no'],
#  ['no'],
#  ['yes', 'no'],
#  ['no', 'yes'],
#  ['yes', 'no'],
#  ['white', 'its white'],
#  ['chocolate', 'cocoa powder'],
#  ['round', 'circle', 'white'],
#  ['yes'],
#  ['table setting',
#   'many plates',
#   'all cups',
#   'fancy settings',
#   'not sure',
#   'several plates',
#   'china',
#   'multiple pizza',
#   'dishes'],
#  ['yes', 'yes on one of them'],
#  ['fork and knife', 'fork knife', 'knife and fork'],
#  ['no', 'yes'],
#  ['no', 'yes'],
#  ['no', 'yes'],
#  ['stop',
#   'to stop traffic',
#   'stop cars',
#   'red for stop',
#   'to signal cars to stop',
#   'so drivers know to stop',
#   'to stop cars'],
#  ['no danger', 'very lucky', 'somewhat', 'lucky', 'very', 'not'],
#  ['stop', 'red', 'right', 'that one'],
#  ['no', 'yes'],
#  ['11'],
#  ['rival',
#   'unknown',
#   'yankees',
#   'orioles',
#   'unsure',
#   'oakland athletics',
#   'pirates',
#   'braves',
#   'padres'],
#  ['2', '0'],
#  ['white'],
#  ['3', '2'],
#  ['no', 'yes'],
#  ['news reporter',
#   'none',
#   'n',
#   'mother',
#   'mom',
#   'no woman',
#   'aunt susie',
#   'no one',
#   'not sure'],
#  ['no'],
#  ['yes', 'no'],
#  ['pictures'],
#  ['no'],
#  ['dots',
#   'check',
#   'white black',
#   'black and white',
#   'dot',
#   'checkered',
#   'polka dots'],
#  ['no'],
#  ['yes'],
#  ['parrot', 'bird'],
#  ['parrot', 'african gray', 'cockatiel'],
#  ['red white and blue',
#   'blue and white and red',
#   'blue red and white',
#   'blue white red',
#   'blue and white',
#   'blue red white',
#   'red white blue'],
#  ['pilot', 'man', 'navion', 'no one', 'not there', 'no pilot', 'no idea'],
#  ['no', 'yes'],
#  ['no'],
#  ['5'],
#  ['yes'],
#  ['2', '0'],
#  ['wire', 'metal', 'wires', 'rope', 'metal wiring'],
#  ['no', '2', 'yes'],
#  ['2'],
#  ['30', '102', 'more than 50', '50', '45', '80', 'lots'],
#  ['no'],
#  ['greenwich', 'greenwich st'],
#  ['yes', 'no', '2'],
#  ['no'],
#  ['fence', 'there is fence', 'fences', 'cage'],
#  ['pike place fish', 'pike place'],
#  ['donut', 'hot dog', 'fish', 'corn dog', 'pastry', 'peanut', 'pretzel'],
#  ['red'],
#  ['yes'],
#  ['yes', 'no'],
#  ['identification',
#   'growth markers',
#   'labeling type of plants',
#   'plant growth',
#   'labels',
#   "to name what's in pots",
#   'label plant'],
#  ['snowboarding',
#   'snowboarding jump',
#   'he went off jump',
#   'snowboarding down hill',
#   'tricks',
#   'ramp',
#   'making ski jump',
#   'jumping'],
#  ['no', 'yes'],
#  ['tent', 'tippee', 'teepee', 'tp'],
#  ['blue'],
#  ['yes', 'no'],
#  ['yes', 'no'],
#  ['yes'],
#  ['snowboarding', 'skiing', 'standing', 'ski jumping'],
#  ['snowboarding', 'skiing', 'boarding', 'jumping'],
#  ['tepee', 'teepee', 'tipi'],
#  ['neither', 'no', 'knees', 'buttocks', 'back', 'on his back'],
#  ['yes', 'no'],
#  ['yes'],
#  ['first', 'pine', 'evergreens', 'conifers', 'pine trees'],
#  ['snow', 'skier'],
#  ['red', 'red and white'],
#  ['swimsuit', 'swim trunks', 'shorts'],
#  ['yes', 'no'],
#  ['yes'],
#  ['yes', 'no'],
#  ['no', 'yes'],
#  ['1'],
#  ['no', 'yes'],
#  ['swim',
#   'shorts',
#   'swim trunks',
#   'swimsuit',
#   'bathing',
#   'bathing suit',
#   'wet'],
#  ['soccer'],
#  ['white', 'yellow', 'white and black', 'white black'],
#  ['player', 'far left', 'gone', 'left', 'shirt', 'on hill', 'outside'],
#  ['5', '6', '2'],
#  ['no', 'yes'],
#  ['no'],
#  ['0'],
#  ['yes'],
#  ['yes', 'co workers', 'best friends', 'coworkers'],
#  ['mixed drink', 'wine', 'cognac', 'red drink', 'sherry'],
#  ['brick', 'bricks'],
#  ['no parking',
#   'cannot read it',
#   'idk',
#   'adopt mile',
#   'slow',
#   'barbecue',
#   'bus stop',
#   'auto',
#   'hello'],
#  ['yellow'],
#  ['land', 'bus', 'school bus', 'road'],
#  ['school children', 'children', 'kids'],
#  ['fairly', 'very healthy', 'very', 'fairly healthy', 'slightly'],
#  ['yes'],
#  ['chicken', 'beef', 'steak', 'pork chops', 'pork'],
#  ['yes'],
#  ['cell phone', 'phone', 'reading', 'pda'],
#  ['no', 'yes', 'pharos'],
#  ['there is no id',
#   'digital',
#   'electronic',
#   "it isn't",
#   'pharos',
#   'phone',
#   'no id',
#   'old id',
#   'gps id',
#   'pharos gps'],
#  ['silver', 'gray'],
#  ['no'],
#  ['english'],
#  ['4', '1', '2', '0'],
#  ['phone', 'cell phone'],
#  ['mirror',
#   'silver plastic',
#   'silver',
#   'rectangular',
#   'old',
#   'clear',
#   'plastic'],
#  ['pharos'],
#  ['no', 'yes', 'maybe'],
#  ['phone', 'gps', 'itself', 'tv', 'nothing', 'gps phone'],
#  ['no'],
#  ['left', 'none', 'right'],
#  ['no', 'unanswerable', 'yes'],
#  ['no'],
#  ['1'],
#  ['no', 'yes'],
#  ['yes', 'no'],
#  ['pharos'],
#  ['pharos', 'smartphone', 'smart'],
#  ['cell phone',
#   'phone',
#   'pharos phone',
#   'pharos gps phone',
#   'gps phone',
#   'gps'],
#  ['phone', 'gps'],
#  ['yes', 'no'],
#  ['baseball game', 'yes'],
#  ['yes'],
#  ['yes'],
#  ['no', 'yes'],
#  ['no', 'yes'],
#  ['shower head', 'shower and bathtub', 'bathtub', 'shower', 'paper', 'person'],
#  ['no', 'yes'],
#  ['white'],
#  ['yes'],
#  ['back wall',
#   'in bathroom',
#   'bathroom',
#   'back of room',
#   'far wall',
#   'far back',
#   'back',
#   'tub',
#   'bathtub'],
#  ['no'],
#  ['2'],
#  ['pink and yellow',
#   'yellow pink',
#   'pink yellow blue',
#   'yellow and pink',
#   'pink yellow and blue'],
#  ['broccoli'],
#  ['yes'],
#  ['2', '1'],
#  ['yes'],
#  ['no', 'yes'],
#  ['1', '2', '3'],
#  ['tile', 'linoleum'],
#  ['yes', 'no'],
#  ['no', 'yes'],
#  ['clear', 'white'],
#  ['no'],
#  ['2:1',
#   '20:0',
#   '50 50',
#   '5 to 1',
#   '4 to 1',
#   'unknown',
#   '60 40',
#   'many more white',
#   '0 to 1',
#   'even'],
#  ['no'],
#  ['drill', 'drill bit'],
#  ['no', 'yes'],
#  ['watermelon',
#   'strawberries and watermelon',
#   'watermelon strawberry',
#   'pineapple',
#   'watermelon kiwi and cantaloupe',
#   'strawberry raspberry',
#   'strawberry',
#   'strawberries'],
#  ['white',
#   'red patterns',
#   'red and white',
#   'red',
#   'red white and pink',
#   'white with red and white sheets'],
#  ['bedroom', 'sunroom'],
#  ['on log',
#   'outside',
#   'on stump',
#   'on fence',
#   'stump',
#   'on wood',
#   'tree stump'],
#  ['bird', 'camera', 'something to pounce on', 'person', 'right'],
#  ['maybe', 'no', 'y', 'yes'],
#  ['fork'],
#  ['beer', 'behind mug', 'wine'],
#  ['pizza'],
#  ['black and white',
#   'many',
#   'black white',
#   'white',
#   'many colors',
#   'black white red blue',
#   'blue'],
#  ['no'],
#  ['yes', 'no'],
#  ['cow', 'dog'],
#  ['kitchen'],
#  ['wood'],
#  ['cooking', 'cook'],
#  ['protection',
#   'ankle brace',
#   'guards',
#   'socks',
#   'shin guards',
#   'protector',
#   'brace',
#   'guard'],
#  ['yes', 'no'],
#  ['catcher', 'umpire'],
#  ['2', '4'],
#  ['rackets', 'tennis rackets', 'tennis racket'],
#  ['rackets', 'tennis rackets', 'tennis bat'],
#  ['8', '4', '6', '7'],
#  ['4'],
#  ['scarf', 'collar', 'nothing', 'necklace'],
#  ['yes', 'no'],
#  ['tennis'],
#  ['1950s', "1960's", "60's", "70's", '1952', '50s', '1955', "50's", '1950'],
#  ['4'],
#  ['woman', 'tennis', 'ones on right', '2 on right', '0', 'right', 'right 2'],
#  ['yes', 'no'],
#  ['yes'],
#  ['no'],
#  ['tennis', 'playing tennis', 'posing', 'smiling'],
#  ['can',
#   'h20',
#   '0',
#   'no container',
#   'water',
#   'wet',
#   'cup',
#   'there is no liquid container',
#   'pot',
#   'jug'],
#  ['nothing', 'play safe', 'not sure', 'hello', 'blank'],
#  ['no'],
#  ['yes'],
#  ['yes'],
#  ['4'],
#  ['0'],
#  ['8', '4', '6'],
#  ['skirts',
#   'tennis skirt',
#   'tennis attire',
#   'tennis clothes',
#   'skirt',
#   'tennis outfit'],
#  ['black and white', 'tennis', 'b&w', 'vintage'],
#  ['no'],
#  ['tennis'],
#  ['racket', 'tennis rackets', 'tennis racket', 'racquets', 'tennis racquets'],
#  ['8'],
#  ['racquets', 'rackets', 'racket', 'tennis rackets', 'tennis racquets'],
#  ['yes'],
#  ['no', 'live', 'neither', 'television'],
#  ['yes', 'no'],
#  ['black'],
#  ['yes'],
#  ['yes', 'no'],
#  ['orange', 'red', 'blue'],
#  ['yes', 'no'],
#  ['30', '56', '0', '20', '32', '40', '50', '45', 'lot'],
#  ['yes'],
#  ['877 pwp green',
#   'call number on side of bus',
#   'phone number on bus',
#   'find number on bus',
#   'number',
#   'phone number',
#   'number on bus',
#   '877pwpgreen'],
#  ['right', 'left', 'north'],
#  ['yes', 'no'],
#  ['yes'],
#  ['dots', 'polka dot', 'polka dots'],
#  ['beach', 'ocean'],
#  ['yes', 'no'],
#  ['horse'],
#  ['horse'],
#  ['3', '4'],
#  ['5', '3', '4'],
#  ['grill', 'brush fire', 'fire', 'bbq', 'barbeque'],
#  ['4', '3', '7'],
#  ['african', 'black', 'african american'],
#  ['blue', 'blue and orange'],
#  ['no'],
#  ['black', 'brown'],
#  ['red', 'black'],
#  ['shorts', 'pants'],
#  ['no'],
#  ['no'],
#  ['down forward', 'backwards', 'down', 'front', 'forward'],
#  ['black white', 'white', 'white and black', 'black and white']]

# %%
import os
HOME_dino = '/root/autodl-tmp/Decomposing-Complex-Visual-Textual-Tasks-into-Intermediate-Questions-for-Multi-Modal-COT/GroundedSAM_src/Grounded-Segment-Anything/'
HOME_dino
# Out:
# '/root/autodl-tmp/Decomposing-Complex-Visual-Textual-Tasks-into-Intermediate-Questions-for-Multi-Modal-COT/GroundedSAM_src/Grounded-Segment-Anything/'

# %%
import os

CONFIG_PATH = os.path.join(HOME_dino, "GroundingDINO/groundingdino/config/GroundingDINO_SwinT_OGC.py")
print(CONFIG_PATH, "; exist:", os.path.isfile(CONFIG_PATH))
# Out:
# /root/autodl-tmp/Decomposing-Complex-Visual-Textual-Tasks-into-Intermediate-Questions-for-Multi-Modal-COT/GroundedSAM_src/Grounded-Segment-Anything/GroundingDINO/groundingdino/config/GroundingDINO_SwinT_OGC.py ; exist: True

# %%
import os

WEIGHTS_NAME = "groundingdino_swint_ogc.pth"

WEIGHTS_PATH = os.path.join(HOME_dino, "weights", WEIGHTS_NAME)

# %%
from groundingdino.util.inference import load_model, load_image, predict, annotate

model = load_model(CONFIG_PATH, WEIGHTS_PATH)
# Out:
# /root/miniconda3/envs/mmcot/lib/python3.8/site-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# final text_encoder_type: bert-base-uncased

# %%
def save_box(img_pth):


    
    image_pil, image = load_image(img_pth)
    tags="cat"
    return image_pil, image

image_path='/root/autodl-tmp/mmcot_test/n157115.jpg'
img_pil, img = save_box(image_path)

# %%
def grounding(image, tags, image_pil):
    box_threshold = 0.25
    text_threshold = 0.2
    iou_threshold = 0.38
    boxes_filt, scores, pred_phrases = get_grounding_output(
        model, image, tags, box_threshold, text_threshold, device=device
    )
    size = image_pil.size
    H, W = size[1], size[0]
    for i in range(boxes_filt.size(0)):
            boxes_filt[i] = boxes_filt[i] * torch.Tensor([W, H, W, H])
            boxes_filt[i][:2] -= boxes_filt[i][2:] / 2
            boxes_filt[i][2:] += boxes_filt[i][:2]

    boxes_filt = boxes_filt.cpu()
    # use NMS to handle overlapped boxes
    # print(f"Before NMS: {boxes_filt.shape[0]} boxes")
    nms_idx = torchvision.ops.nms(boxes_filt, scores, iou_threshold).numpy().tolist()
    boxes_filt = boxes_filt[nms_idx]
    pred_phrases = [pred_phrases[idx] for idx in nms_idx]

# %%
def readimage(img_dir, )
